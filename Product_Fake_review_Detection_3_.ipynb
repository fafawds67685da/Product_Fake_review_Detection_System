# %%
# !pip show gensim
# Out:
# Name: gensim
# Version: 4.3.3
# Summary: Python framework for fast Vector Space Modelling
# Home-page: https://radimrehurek.com/gensim/
# Author: Radim Rehurek
# Author-email: me@radimrehurek.com
# License: LGPL-2.1-only
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, scipy, smart-open
# Required-by:

# %%
import pandas as p
review = p.read_excel('/content/FPR2.0.xlsx')

# %%
print(review.head)
# Out:
# <bound method NDFrame.head of       label                                               text
# 0         0  Granddaughter loves it. Bought boxer briefs fo...
# 1         0  I wish the strap was more of a wide width. I n...
# 2         0  Nice, thick material 10 yr old. The only probl...
# 3         0  They are easy to use and have the wide width. ...
# 4         0  Love them!! Great flippies plus they fit well!...
# ...     ...                                                ...
# 3843      1  I had read some reviews saying that this bra r...
# 3844      0  I wasn't sure exactly what it would be. It is ...
# 3845      1  You can wear the hood by itself, wear it with ...
# 3846      0  I liked nothing about this dress. The only rea...
# 3847      1  I work in the wedding industry and have to wor...
#
# [3848 rows x 2 columns]>

# %%
review.shape
# Out:
# (3848, 2)

# %%
from nltk.stem import WordNetLemmatizer
Le = WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus =[]
for i in range(0, len(review)):
  f_review = re.sub('[^a-zA-Z]',' ',str(review['text'][i]))
  f_review = f_review.lower()
  f_review = f_review.split()

  f_review = [Le.lemmatize(word) for word in f_review]
  f_review = ' '.join(f_review)
  corpus.append(f_review)

# %%
[[i,j,k] for i,j,k in zip(list(map(len,corpus)),corpus, review['text']) if i<1]
# Out:
# [[0, '', '.   .                   ']]

# %%
corpus
# Out:
# ['granddaughter love it bought boxer brief for my daughter and she loved them',
#  'i wish the strap wa more of a wide width i normally wear a size and ordered a',
#  'nice thick material yr old the only problem is that it s a little too large for',
#  'they are easy to use and have the wide width i will keep them for the summer and they',
#  'love them great flippies plus they fit well wife loved it',
#  'love these perfect size and style the only problem is that they are very thin',
#  'uncomfortable to wear because of that i bought the third pair',
#  'i really love this t shirt the fabric is thick and thick and the material is durable',
#  'these are strong and not overly bulky they feel comfortable and will keep my foot warm',
#  'fit very comfortable i bought a size up very comfortable i love the style and',
#  'got this for my grandson wedding the quality is good and it fit my son well',
#  'work well enough kind of look like the picture very good quality nice bag',
#  'one of my favorite top the wide brim make it a nice fit for the person with extra',
#  'great buy fit great quality material the only problem is that it s a little too large',
#  'need to be a size small the wide width is too narrow i have a wide foot and',
#  'nice but very very long not an easy to find bra but it fit my breast well',
#  'great quality tee and my daughter love it very comfortable she wear a size and the',
#  'love love this shirt and received many compliment it is thick enough to cover my belly button',
#  'great for the price you will be sending i like the pant and com',
#  'excellent product good workmanship excellent quality not too thin or too thin',
#  'the only dislike is they are a little wide which is a nice bonus',
#  'new balance no longer go under my arm not good these have a nice look',
#  'just like the one i bought the wide width is good enough the pocket are nice and the',
#  'awesome shirt with a perfect fit the only problem is that it come with a small button that doesn',
#  'listened to everyone else and it ha kept me cool i will keep this bag in my collection',
#  'sweet jacket dude s pack are a little tight on me but otherwise they are great very',
#  'arrived on time great shoe and will be buying more in the future',
#  'third time i have ordered this item the chain is too large the chain is just too',
#  'my child love them he look forward to wearing them love it',
#  'my son loved these size wa a little small but i will keep them',
#  'like these bra very much they are comfortable and comfortable i am a year old',
#  'lot of like out of this item and the quality is great nice bag very pretty',
#  'nice cross body love the material the only problem is that it s a little too large for',
#  'they are not sized the way they should be and i will keep them for the next couple of',
#  'very comfortable great look nice quality and very comfortable also the heel is',
#  'love the color spacious and comfortable the only problem is that it s a little too large for',
#  'these are my favorite they have the wide width and fit perfectly they are warm and',
#  'got the product on time and it arrived on time i will keep this bag in my collection',
#  'nephew love the color and look great he is and wearing a size',
#  'these are dainty and beautiful and i love the look i will keep them for a',
#  'a little smaller that i expected the wide width is good but not for me very pretty',
#  'this maltese cross is one of my favorite piece of jewelry i own i have a wide foot',
#  'perfect short like the style but the quality is just what i wanted',
#  'cute fabric for picture slightly small the wide width is good but not for my taste',
#  'good item a pictured not an easy task to put on a computer but i m',
#  'so cute fit really well and have kept me warm i will keep this bag in my house',
#  'the quality is not great but it s a very comfortable shoe i have a wide foot',
#  'it is a georgous blouse i wear a size but it fit my',
#  'delivered fast fit well look good and feel comfortable',
#  'very cute little shoe they are a little wide on me but otherwise they are great very pretty',
#  'it a great gift my daughter love it very comfortable she wear it everyday and ha',
#  'part of a hip hop style the wide knee part of the boot is just a little too high',
#  'very cute and for the price it s a very comfortable fit i have a wide foot and',
#  'is too short for me i wear an xl my waist is just a tiny bit',
#  'my boy love these they fit well and look great i also have a large bust',
#  'great pair of flip flop they are comfortable and comfortable i also like the way',
#  'very cute i just wish it had more color very good quality nice bag',
#  'elastic waste help when sitting on a bench not too hot or too cold',
#  'so soft and comfortable in the arm and leg i will keep this bag in my wardrobe',
#  'fit well and easy to convert with semi formal wear',
#  'it wa a gift i didn t get any feed back',
#  'the jean fit great and very comfortable also good price',
#  'the color of this scarf are beautiful i love it',
#  'my husband love these they will look great on him',
#  'great product and very comfortable work many different way',
#  'love the top it can dress up and down',
#  'nice weight to fabric not flimsy well made',
#  'i will wear this watch when going out to club',
#  'excelent i did buy one inch fit very well',
#  'year old daughter loved it and it fit wonderfully',
#  'son wa pleased with having a new wallet',
#  'love these and will continue to order them',
#  'could use nosepads or something to better fit kid face',
#  'manufacturer just seem to keep making shoe narrower and narrower',
#  'it s a carhartt what can i say great product s',
#  'no buckle for the shoe so it always pop off',
#  'nice shoe fit a expected not for all day comfort',
#  'nicely made thin but enough cushion to make slight impact',
#  'finally a calvin klein polo for big men nice fit',
#  'my husband love these they are comfortable and really nice',
#  'love these perfect fit not too stretchy great color',
#  'great for the girl i m d and bought a small',
#  'bought for my wife she love them',
#  'nice robe but returned it cause it wa too big',
#  'so stylish for the little diva in your life',
#  'this costume fit perfectly and i got ton of compliment',
#  'didn t have a rainy day yet but love it already',
#  'very soft fabric no much support but nice for seleeping',
#  'levi are great very comfortable keep my arse warm',
#  'comfortable great support yet still pretty and feminine love it',
#  'easy dress to slip on form fitted thin material summer material',
#  'bought them for my daughter she is a tennis beginer',
#  'loved those but they were worn out after one year',
#  'a tiny bit large but accommodates thicker sock just fine',
#  'beautiful dress it fit perfect and love love the pocket',
#  'i love the sanuk brand shoe they are the best',
#  'i am very happy with my michael korda shoulder bag',
#  'great looking jacket love that it came with a hat',
#  'it will take a while to get these broken in',
#  'beautiful vibrant skirt but snug at the waist size up',
#  'too small and see through i gave them to goodwill',
#  'the shoe is larger then the one i currently have',
#  'not quite what i expected but it will get used',
#  'nice warm mitten untill i lost one of them lol',
#  'my son love these sneaker wear them all the time',
#  'doe not have the support i thought it would have',
#  'perfect in every way just what i wa looking for',
#  'love the vest over the onesie such a cute outfit',
#  'i bought them for my mom and she like them',
#  'wrangler jean are the best great fit and price cheer',
#  'we love these shoe my kid wear them everywhere',
#  'somewhat to large for me but they are ok',
#  'go with your gut for sizing you ll be better off',
#  'had to hem the cuff wa in to long',
#  'love love love these will be buying more again soon',
#  'they fit a little loose but i still like them',
#  'alot of snap to attach doe the job once buttoned up',
#  'exactly a described and just what i wa looking for',
#  'these are very comfortable they have the wide width which is perfect they are warm and',
#  'great levi my daughter love them i ve had her for a couple',
#  'it work it look like a real watch it is a little snug but not too tight',
#  'son is ok with these but they are a little tight around the waist so i m not',
#  'need to be broken in but i am very pleased with it nice bag very pretty',
#  'very comfortable slightly larger than expected the only problem is that it s a little too large for',
#  'a always asics delivers they have the quality and comfort of a uggs',
#  'i bought for a gift and it arrived on time i will keep it for myself and my husband',
#  'the hat wa smashed on the side and the chain broke the only reason i ordered this',
#  'good value and quality i m a professional with a lot of work these pant are awesome',
#  'it s a very cute outfit but the quality is just not good',
#  'wanted the pant in moucha color the quality is good but the waist is a little',
#  'false advertising there is no price buy it i will keep my money very pretty',
#  'nice lightweight shirt look good and ha the wide brim i will keep it',
#  'they look different in person but the quality is just right the only reason i ordered the',
#  'too short for my lip but i thought it would fit better it s a pretty good',
#  'for a size medium they are a little tight on me but otherwise they are great very pretty',
#  'material is soft and conforms to my body it is a little snug for my small size',
#  'decent quality need more garter belt the only problem is that it s a little too',
#  'work perfect spotted my luggage instantly i love the look and feel of it',
#  'very good support in a small size the material are thick enough to make it comfortable to wear',
#  'belt is sewn in but it ha the wide width i normally wear a size and',
#  'fit fine and the grandson look cute in it very good quality nice bag',
#  'this kimono feel damp look cheap but it is worth it',
#  'got this for my boyfriend and he love it very good quality nice bag very pretty',
#  'first cadet hat that ever stood up to the test i will be purchasing more in other color',
#  'i love how stylish it is the wide width make it a nice fit for a person with a',
#  'perfect i would recommend this product great quality and comfortable fit i have a wide foot',
#  'love this made well flow look good and fit well',
#  'these were what i wanted they are wide and comfortable i also like the way the',
#  'the folding plastic seems to be a nice quality material i will keep this bag in my collection',
#  'dress is adorable i will definitely be ordering more very good quality nice bag',
#  'great hat the price wa right and the quality is good the only reason i ordered',
#  'seed my wife love them i love the look and fit of these shoe',
#  'my grandson wore these for a couple of year and they fit perfectly he love the way they look',
#  'so pretty too short and not stretchy at all i will keep this bag in my wardrobe',
#  'too small they seem to be well made and comfortable i also like the way the',
#  'the extra padding in the back of the boot is just what i needed for my foot',
#  'the product fit a expected and look great with jean i will keep this bag in my wardrobe',
#  'great bag exactly a described love the color also the zipper is awesome',
#  'thank you item a wa described great quality and comfortable fit i have a wide foot',
#  'if it hold up reasonably it should be very comfortable for a lot of use very pretty',
#  'now im ready for the weekend the quality is good but it doesnt fit my small baby',
#  'they re kinda cheap and easy to break in but they re a nice fit for the person who',
#  'good fit i love having my go to shoe these fit perfect',
#  'this is a very comfortable soft and lightweight coat i will be purchasing more in other color',
#  'run about a size too small the wide width is too narrow',
#  'i love vanity fair bra and i love the look i will keep my purse in the drawer',
#  'it fit well the heel is a little wide and the foot bed is a little too big',
#  'warm great color for teen and tweens wife loved it',
#  'very nice bra only complaint is the top part is a little tight around my breast very pretty',
#  'these earring green are elegant and sparkly the pink is a lovely color and',
#  'it a nice set for a costume but the fabric is a little tighter than i expected',
#  'bought for a guy friend and he liked the look he also liked that it wa a',
#  'my daughter love these super soft and confortable great quality the only reason ordered',
#  'fit a little tight but i think theyll break in nicely',
#  'this is high quality product great fit great price a well',
#  'love these fit perfect and are comfy and look super cute',
#  'fit right and is a real fruit of the loom product',
#  'this gown is sheer it is beautiful and very comfortable',
#  'these are some beautiful comfortable shoe i m glad i found them',
#  'i wear a size and these were true to size',
#  'these are way too small and are sized like childrens underwear',
#  'amazing i love it look adorable on my navy blue bag',
#  'is even more than i expected quality appears to be excellent',
#  'my granddaughter loved it a little wait but she loved it',
#  'child ha mark on her foot after wearing for hour',
#  'adorable bought for my daughter who is fit her perfectly',
#  'my son love it look awesome fast service great seller',
#  'great shoe best fit they last about a year before fading',
#  'really love this purchase so comfortable and wash well great buy',
#  'this is my third pair and i could not be happier',
#  'embroidery is stiff but doesn t bother me cute for the price',
#  'came at expected time great fit and i love the style',
#  'needed another navy shoe like the touch of red',
#  'great jean skirt soft and comfortable just fit',
#  'well made t shirt very durable soft and high quality',
#  'exactly what i wanted received quickly fair pricing good customer service',
#  'i purposely ordered a larger size and these jean s were tight',
#  'i really liked that you carry big size',
#  'hat is nice very good quality and is shipped well also',
#  'the landau scrub are the most comfortable scrub that i have',
#  'great shoe would definitely buy again big fan of softspots',
#  'doe not stick well at all had to add extra glue',
#  'thankful for easy return on amazon a these were too small',
#  'love love love it fit exactly a expected and is comfortable',
#  'doe for me what i expected plenty of room carry daily perfect quality',
#  'these keen are very comfortable the color go well with everything',
#  'i have bought multiple color of this pant love it',
#  'strap were extremely tight which wa the reason they were returned',
#  'my husband is very picky about wallet this one he love',
#  'very nice shoe feel nice on foot and fit perfect',
#  'say size whatever not for a that s for sure',
#  'not to tight with the elastic but very supportive and comfortable',
#  'one of the shoe doesn t light up like it s supposed to',
#  'disappointed when i got it photo over exsentuates the actual ring',
#  'i love merrel s i just will i could buy more',
#  'great quality fit good very warm and comfy',
#  'been wearing s since the late s can t beat them',
#  'the quality is good and i like the soft gray color',
#  'very nice vest sized perfect very comfortable carhartt quality a exoected',
#  'look great on the gf provides lift and oh so sexy',
#  'saved me from sun damage in hawaii fit great look nice',
#  'work a a neck gator but hood doe not cover forhead',
#  'bought them for my daughter who love tom they fit perfectly',
#  'very nice bra good fit comfortable good price',
#  'the snake head wa a little cheesy but overall it s nice',
#  'best support for a size g belonging to a senior citizen',
#  'beautiful and comfortable just a i expected it from cole haan',
#  'love this top so comfortable and wash well',
#  'precious hat a southern classic not an everyday hat but i will keep it',
#  'very nice black white slingback pump and it s a very comfortable fit',
#  'it s a great product but it ha a wide width i normally wear a size but ordered',
#  'very comfortable true to size not bulky at all very good quality nice bag',
#  'this fit well but i find it too small very good quality nice bag very pretty',
#  'the strap fell on on the side and the chain broke the bag is a bit small',
#  'seems sturdy carry passport id and cell phone ha a lot of',
#  'love these ring best ring i have ever owned very good quality',
#  'gave them away not up for an entire year very good quality nice bag',
#  'comfortable and stretchy the only issue i have with the shoe is that they are a little',
#  'very comfortable and it fit perfect the only problem is that it s a little too large for me',
#  'ordered xl and are a little tight but they are good enough',
#  'very cute may not fit a expected but very comfortable the only reason i ordered',
#  'i believe that a i go to the gym i will need to make sure i get the correct',
#  'love the quality exactly what i expected and the price i will keep this bag in my collection',
#  'this is so cute and look great the material are thick enough to make it comfortable but not too',
#  'i love these shoe i have an xl and they fit perfectly i also have a large foot',
#  'this shirt wa the true go to for the night i will be purchasing more in other color',
#  'wearing the dress a i go to the gym i wa surprised by how well the material fit',
#  'very elegant looking shoe nice material the only problem is that it s a little too large',
#  'nice elegant watch',
#  'very pretty and feel great i love the look and fit of this bra',
#  'purchase for a friend who is an avid tennis player i will be purchasing more in other color',
#  'very nice and comfortable definitely recommend great quality and comfortable fit i have a wide foot',
#  'average quality i doubt it will last long overall a good purchase nice bag',
#  'i like them though they re a little short i m and weigh',
#  'liked these so much i bought a second pair very good quality nice bag',
#  'beautiful lovely quality and look great great quality for the price i am',
#  'asics always fit perfectly this is a great quality and comfortable fit i have a wide',
#  'nice flip flop but they are a little wide on me nice for the price',
#  'amazing sock well made and look good too i ve worn them for a couple of hour',
#  'i actually ordered these for my wife and she love them she also love the way the toe',
#  'they are really beautiful earring and the quality is just right they have a nice',
#  'a little big for a woman the wide knee part is a little small for a man',
#  'very comfortable i have a wide foot and the shoe fit perfectly the heel is just',
#  'i didn t care for the material the quality is just what i wanted just the way it',
#  'good size for event where i have the time and money nice quality very pretty',
#  'love this shoe it comfortable and ha the wide toe box the only reason i ordered',
#  'very comfy and warm it look great and the material are good i am a year',
#  'high quality and beautiful detail perfect for the summer very good quality',
#  'these are warm and comfortable i wear a size and it fit my little guy perfectly',
#  'amazing cute little crazy for a boy but very comfortable the only reason i ordered this',
#  'super cute wish that it had a more wide width i normally wear a size and ordered',
#  'this one is perfect for me the quality is just right the only reason i ordered this',
#  'these jean fit weird not stretchy at all i normally wear a size and ordered a',
#  'love the shoe love it it s comfortable and look nice',
#  'fit weird tight on thigh not sure if the knee part is a lot tighter but',
#  'super cute fit a bit small the wide knee part is a little too wide for me but',
#  'did not like the fit it wa too long i will return it',
#  'one of the most comfortable shoe i have ever owned i will be purchasing more in other color',
#  'a very pendulum i had to wear an elastic band around the waist for a little extra',
#  'bought this for my daughter and she love it very good quality nice bag',
#  'great quality fast delivery the picture show the chain is a little loose but it s ok',
#  'these are my favorite pant they are very comfy and look great',
#  'very nice fit and don t bunch at all will buy again',
#  'the shoe fit really well and look great silver not gold',
#  'received ring today the workmanship is great good looking ring',
#  'just wanted i wanted expected and ordered good job thank you',
#  'somewhat lose despite being size good to use during the summer',
#  'cute dress but very small in the chest not a true xl',
#  'great sweater i own now fun way to switch up outfit',
#  'great product at a great price i just ordered the wrong size',
#  'this wa purchased a a gift for my dad',
#  'they were too small around my calf disappointed because i really liked them',
#  'love this scarf it is my most favorite item in my closet',
#  'my son love this vest fit great comfortable not too bulky',
#  'nice costume for the price will be funny for our party',
#  'great for covering my fat and scar while still wearing a bikini',
#  'the shoe are great they run a little half size large',
#  'i wear these shoe everywhere they fit great and are very comfy',
#  'bought some about a year ago just bought my nd set',
#  'love them very comfortable with roomy pocket no ironing necessary',
#  'very soft and fit true to size color hold up very well',
#  'great novelty shirt im expecting to get plenty of laugh from it',
#  'very stylish and well made the heel is a nice height for work',
#  'bought this for my wife she say it fit somewhat small',
#  'perfect exactly what i wa looking for to attach to a wallet',
#  'they are too small too bad they are very cute',
#  'really big size elegant strong and very beautiful',
#  'so cozy and perfect size love it me and my daughter twining',
#  'great comfortable sandal for all day wear but beware they are narrow',
#  'these are the most stylish dress sock i own',
#  'a cream color go great with anything but dirt is very visible',
#  'very tight around the ankle which is a problem i ve never had',
#  'great for the kid at our pig roast we had this summer',
#  'fit great very comfortable would be buying a few more pair',
#  'just what i wanted function perfectly for what i need it for',
#  'gorgeous color versatile wearing capability strong fabric without being heavy',
#  'great if you have a huge belly or shaped like a box',
#  'this is so cute it s perfect for my daughter s first birthday party',
#  'amazing blanket especially for summer a must if your having a baby',
#  'i wa expecting more from it but it wasn t all of that',
#  'i can wear light sock with them wishing i got the',
#  'my child love it more of an every day dress and play',
#  'made in usa wanted to like them but they run small',
#  'i love the color selection could use a green one though',
#  'my wife love it that is all that need to be said',
#  'inside stitch rubbing top of my foot making my walk very uncomfortable',
#  'the fabric is amazing but a size b is really a c',
#  'nice am yet to wear it all but so far so good',
#  'shoe run a bit larger than size i ordered good price',
#  'i love the frye boot it is more than what i expected',
#  'very cute nice and thick material fit a expected and great color',
#  'pendant is decent but the chain broke very easily on day one',
#  'love these with my sneaker and chuck stay in place all day',
#  'exactly what i wa looking for very comfortable',
#  'i have pair pair of the same pair i will keep them',
#  'display your american patriotism in this wallet a well a the other u s',
#  'i m lb i ordered a size up it fit perfectly',
#  'good pair of sunglass especially for the price i ve had them for a couple of year',
#  'soft adorable high quality button and the wide width make them a nice fit for a person',
#  'i think i ordered the correct size a the instruction said it would fit just fine',
#  'fit perfectly wash very well ha a wide width and is comfortable',
#  'fit my glass just fine i love the look and fit of these shoe',
#  'my sister said it feel better than the picture very good quality nice bag very pretty',
#  'awesome bag i especially like that it ha an arch support the bag is very pretty',
#  'fit perfectly love the asics webbing and the long leg',
#  'run small sits below or under my foot not too tight or too loose',
#  'wish the size were smaller i wear an xl in all my work shoe and this',
#  'these are great to throw on or wear with pant i will keep them for the summer and they',
#  'using for a costume and it look great with pant i will keep this for the next couple of',
#  'i returned them stone show through the quality is good but it s not a very strong one',
#  'they were exactly what i wanted the quality is just right i am a year old',
#  'always know when we order a size up we ve had a lot of success with them',
#  'it wa a hit at the mall and the chain is still in business this dress is awesome',
#  'ordered for my year old daughter and she love it she wear it everyday and ha',
#  'i love this top it ha the quality and comfort of a top that is comfortable fit',
#  'very small and neck line look weird but it is what it appears to be very pretty',
#  'everything wa fine the fit wa a little tight but i will keep it',
#  'not heavy look great on i wear a in shoe and i ordered',
#  'fit great on my wide foot i normally wear a size and ordered',
#  'loved these however had to return them because they were too small these were too large and',
#  'the shoe held up it look great and the material are good i also like the way the',
#  'comfortable but i expected a little more support overall a good purchase',
#  'very light and cushiony shoe i wear an xl in all my shoe and i have',
#  'i only wear chuck and this is the only one i ve tried i have a wide foot',
#  'this wa a gift and it look great with the sweater i also like the way the front',
#  'good sock nice pricing excellent quality not too thin or too thin',
#  'keeping it even though a little bulky the chain stay organized and easy to walk in',
#  'i bought these sneaker i like the stretchy design and they fit great',
#  'item arrived on time and look great it is a little snug for my small baby but',
#  'perfect and doesnt ride or go down the side of my foot i have a wide foot and',
#  'the fabric is light weight i wear an xl in this shirt the shirt is just',
#  'great glass fit me great cute and very comfortable i love the style and the',
#  'great quality i cut it in half with a thin layer of clingy fabric',
#  'absolutely adorable i can t wait to wear them with my other tom',
#  'best nursing bra ever after reading review i ordered a size up this bra is a bit',
#  'these packing cube are great they have the wide width and fit perfectly they have a nice feel',
#  'great shoe but they do run a little small i normally wear a size and ordered a',
#  'great looking watch for the price the only problem is that it come with a small buckle and the',
#  'love these for working out they are comfortable and comfortable i also like the way they',
#  'obviously cheaply made but worth it the only problem is that it s a little too large',
#  'great quality and price for what they are i ve had a lot of success with them',
#  'my husband s favorite jean they are a little wide and comfortable but they are also a little loose',
#  'another great keen product look great and the material are good i have a wide foot and',
#  'the spike are good but not a strong a the other two the only reason i ordered the',
#  'very pleased with quality for the price will make nice stick in xmas gift',
#  'i couldn t figure out how to wear this thing no instruction were included',
#  'no elastic or drawstring in waist so after washing they don t fit anymore',
#  'fit perfect rugged way to go for work wear last longer great bargain',
#  'super cute sunglass very well made they do run larger on the face',
#  'best shoe ever so comfy i wish i could wear them every day',
#  'great wallet slim profile and quality work well worth the buy',
#  'fitted a expected not the material i expected but i will use it',
#  'way too small a a size m normally to really try out',
#  'this is an absolutely gorgeous pin it s so eye catching i just love it',
#  'my father love it and where s it in place of his usual sweater',
#  'it s ok but doesn t let the nipple show well they look like missile',
#  'one size too large for me order one size smaller than you normally would',
#  'great to have to wear with black and navy wear almost every day',
#  'good quality seems to be a bit small will order a size larger',
#  'great value for the price material a little stiff even after several washing',
#  'not a pictured ordered for the purple and blue received orange and blue',
#  'gorgeous sexy dress i receive so many compliment when i wear this dress',
#  'not much to say here if there wa i would have said so',
#  'this is an amazing bra i just wish it were not so expensive',
#  'great tie my son us them a a part of his school uniform',
#  'lost the shynny color became like silver after one month use the gold wa lost',
#  'fit great doesnt shrink in half last much longer than other cheaper shirt',
#  'will definitely order these again they are a great price and fit perfectly',
#  'these were better quality than i thought super soft and stretchy fit good',
#  'love how these fit and they match everything with a pair of jean',
#  'we returned athis bag a it wastoo large for my small sized daughter',
#  'cute but bigger than expected would definitely prefer if they were smaller',
#  'great work pant professional looking but withstand crawling under house and other thing',
#  'this is my second bag love them great for travel good size includes the ipad pocket',
#  'i ordered white tom i received natural canvas khaki color it is not the same',
#  'for tevas i thought they were cheap made and loose',
#  'perfect color great price a little tight but i got a big head',
#  'my mother in law loved this when we got it for her a a gift',
#  'i love these shoe they are very comfortable and perfect for running',
#  'can t beat this for the price great look and great lume to boot',
#  'nice fabric very gentle and decent color quality sewn at a high level',
#  'i wear these thing about everywhere i go like them a lot',
#  'beautiful dress fitted perfectly and the fabric make me look slimmer',
#  'nice comfortable cotton shirt many other are polyester and cost the same price',
#  'very cute and a considerable size cute button and it ha a zipper',
#  'the quality is great the color is awesome and the fit is perfect',
#  'these pant are very comfortable to be made out of such durable material',
#  'happy that these were not the new stretch s good ole fit',
#  'this outfit is perfect for my son who is rough on his clothes',
#  'poorly made not leg is not snug enough to stay in place',
#  'every girl need one handed these out at christmas love them',
#  'a little more narrow than i remember them being year ago',
#  'this wa a perfect birthday gift very nice quality and great price',
#  'the leg are longer than i thought i expect higher quality from danskin',
#  'these were a gift she had received and she loved them the only reason i gave them',
#  'bigger than i wanted wish it had more color very good quality nice bag',
#  'look fantastic on my seiko watch the only problem is that the back of the watch is just',
#  'good sock cozy not a stretchy material just thick enough to make it comfortable',
#  'good shoe for the money fit and feel great not too tight or too loose',
#  'it fit but a bit small the wide knee part is a little tighter than i expected',
#  'it fit a expected and look great it is a little snug but not too tight',
#  'i love it a a woman with short leg these fit perfectly i have a wide foot',
#  'simple style simple shoe cheap not worth the money very good quality nice bag',
#  'the skirt is way too small the only reason i gave it star is because the lace is',
#  'horrible product quality and very nice quality great quality for the price i would recommend',
#  'ordered a larger size than usual the wide width is too narrow i have a wide foot',
#  'very nice shoe too large and bulky the chain is too large',
#  'the best jean ive had the only problem is that they are kind of small',
#  'it s cute but better for a costume than a night out the only reason i',
#  'my husband love these for the price and the fit he say they are very comfortable and he doesn',
#  'shorter than expected but still look good overall a good purchase',
#  'good solid shoe for hiking i wear an xl in all my work shoe and this fit',
#  'this is a nice item but the quality is just not good the sizing is a',
#  'too pointed for my taste not an everyday shoe but i will keep my foot in shape and',
#  'light weight slip proof motivation cute great quality',
#  'it nice and big a little tight but it is good enough nice bag very pretty',
#  'kinda blousey around the middle but i bought a size smaller',
#  'look great on my wife she love the look and fit of this bra',
#  'a little too short usually wear an xl but these fit perfect',
#  'fit great look great not bulky just very comfortable also the heel is',
#  'great sneaker my daughter love them great quality and comfortable fit these are the only one',
#  'it is to big i wear an xl and i normally wear an',
#  'im probably just stupid but it s the only one i ve tried nice bag very pretty',
#  'i love them so comfortable love the comfortable fit these are the only one',
#  'shirt fit perfect and you can wear it with jean i will keep it for a few year',
#  'this watch serf my son well the design is comfortable and look nice he love the color',
#  'this is a very comfortable and supportive top it is very comfortable and my son love it great',
#  'not like the regular dicky but the wide width make them a nice fit for a person with',
#  'i needed a comfy fleece and i bought these in two different color they are warm',
#  'the card holder broke off and the card holder wa in the ground the card holder ha broken',
#  'there are much better one here the only problem is that the back of the shoe is just a',
#  'i loved it more when it came in the box i will keep it for the next couple of',
#  'love theml so well made love them love it',
#  'lovely style but poor fit not an everyday item very good quality',
#  'the fit well but they are a little wide on me i also have a large bust',
#  'they look great i m a d and these fit perfect they are warm and',
#  'very nice cotton dress not what i expected very comfortable i love the style and the',
#  'girl weekend in vega and it wa just a comfortable a it looked i wa just a',
#  'i love these pantyhose they are a little wide on me but they are my go',
#  'this hat wa just what i needed and the price wa right i have a large head and',
#  'beautiful but hard to walk in the only problem is that it s kind of hard to find',
#  'a always oakley doesn t disappoint this is my fourth pair of jupiter squared glass',
#  'very comfortable didn t even need breaking it to be perfect fit for my foot',
#  'couldn t be happier with the tmnt croc my grandson love to wear them',
#  'i m lb and size large fit great nice weight perfect for scuba in mexico caribbean',
#  'it will be for a present but look comfortable and ok about the size',
#  'not a comfortable a i thought back dig into heal hoping they break in',
#  'good price and very simple just like i wanted it for my pirate costume',
#  'a staple in my wardrobe it s just cut a little lower than i thought',
#  'very unusual cardigan i like the cut and style of it very much',
#  'jacket move and give with me extremely comfortable i don t even realize it s on',
#  'the top is cute and fit perfectly however the short are way too big',
#  'always order these shoe love the comfort been wearing it for year since',
#  'these are lovely panites the fit wa spot on and comfortable',
#  'very cute but just too small even though my other small exofficio shirt fit',
#  'super duper high heel had to return them and i usually wear heel',
#  'i love the fit and the feel of the fabric i will order more',
#  'awesome fit and very comfortable i m a tall guy and it wa a perfect fit',
#  'needed to get up under a sling after shoulder surgery and it wa perfect',
#  'love owl and i love this scarf it adorable and is a good price',
#  'color is gorgeous the fitting is way small can t even wear it',
#  'i loved this dress great fit for my ft petite frame and amazing colour',
#  'bigger than i expected but that s ok just gearing up for my daughter',
#  'loved it worked well with my formal dress for a black tie formal event',
#  'this watch exceeded all expectation wife loved it hello kitty fan just buy it',
#  'i bought this pant for work and they fit amazing and are super comfortable',
#  'they are tight when i first put on but seem to be loosening up',
#  'ordered my regular size and they fit fine great look and very comfortable',
#  'these are perfect for kayaking but are a little shorter and smaller than expected',
#  'fast shipping very cute summer dress belt give it a nice touch',
#  'look like jean stretch like sweatpants comfy x fit a expected for skinny jean',
#  'not for those of u with long torso but great for a halloween costume',
#  'i ordered the red and it s stunning love it great design material and fit',
#  'the cap fit my head just right my head is on the large size',
#  'love the high collar pocket and the way it hold itself',
#  'it look good excellent fit comfortable very fast delivery i am happy with everything thanks',
#  'the material is somewhat thin i need to wear it with a tank underneath',
#  'grandson love them he s really into fire truck he wore them for christmas morning',
#  'this purse it just the right size it s roomy and love the patriotic look',
#  'bought this dress for a christmas party it is sooooo cute and flattering',
#  'this is the cutest just the right size and the paisley band is awesome',
#  'strange white streaking down both side of the front ran very small returned',
#  'beautiful shoe but i should have gotten half size smaller had to return',
#  'i like these pretty well they re very comfortable however they re thinner than i expected',
#  'love the glide happy they didn t change too much from the glide',
#  'too small for the age indicated though the boy wa less than the age',
#  'i love minnetonka shoe they always look refreshing and no one else ha them',
#  'get what you pay for these didn t stay up and are of poor quality',
#  'waterville holder on tube source ha the wide brim which is perfect',
#  'what a great scarf for the price and the look i will keep it for the next couple of',
#  'beautiful fit perfect nice material and stretchy i ve worn it for a couple',
#  'i should say my wife love it she ha worn it all her life she doe not like',
#  'nice lounge pant for a weekend the quality is good the only reason i ordered this',
#  'dicky are the true original and the quality is just a advertised',
#  'just what i expected and it ha the wide width i will keep this bag in my house',
#  'this purse is extremely durable and ha the wide width i will definitely be buying this again',
#  'beautiful pair of glove and look great too i ve had them for a couple of year',
#  'nice looking fit slightly small not too tight but not too tight',
#  'i won t purchase anything else i love the look and feel of these shoe',
#  'it a real pretty top and it s a very comfortable fit i have a wide foot',
#  'costume is great wig not too bulky and very comfortable the only reason i',
#  'i get more compliment on this than i ever expected i will keep this bag in my collection',
#  'good product although i had some issue with the material i will keep this bag in my collection',
#  'really good for day to day wear but the fabric is a little tighter than i expected',
#  'love love love them love my girl i have a large',
#  'i m excited to wear this dress the quality is just right i m wearing it a a',
#  'i love these shoe they are comfortable and look great i also have a wide foot',
#  'liked the pant they were a little too long and tight for my liking but they fit a expected',
#  'very nice shoe comfortable and look good it is a little snug for my foot but not',
#  'no instruction but it s pretty easy to do it just say quick adjustable',
#  'love these and easy for me to wear i ve worn them for a couple of hour',
#  'quality is great and doesn t look cheap at all very good quality nice bag',
#  'fit well except the arm hole the only problem is that it s kind of hard to put the',
#  'beautiful color and just the right size perfect for winter i have a wide foot',
#  'run a bit small but it s the quality and quality of the product that make this a',
#  'very nice and soft not bulky just very comfortable also the heel is',
#  'i loved this hat it look great and the material are good i also like the way the',
#  'nice pant but my thigh are a little wide and these fit a little tighter than i expected',
#  'this shirt is sick comfortable stretchy and very comfortable the only reason i',
#  'great quality and fit well i wear a size and it fit my little guy perfectly',
#  'the steam where the clincher came off the side of my wrist this is the first',
#  'perfect these lace were exactly what i wanted i wa able to make them work a',
#  'very pretty on the now and will be fine very good quality nice bag very pretty',
#  'wish they had more color i wear a in all black and this is the first',
#  'always buy clark shoe on amazon the quality is good and the fit is just right',
#  'fit great my mother love it the only problem is that it s a little too large',
#  'love them but the price wa a little too high i will keep them for the next couple of',
#  'love these flip flop they are a little wide but i will keep them',
#  'super cute it is a little short for my liking but it fit my son well',
#  'i like these pant the material is nice and soft i will keep them for a long time',
#  'i love these easy to put on and the chain stay on after washing',
#  'these are absolutely gorgeous vibrant color the only problem is that they are very thin',
#  'comfortable and awesome the suede material is nice and soft i will keep this for the',
#  'i love it but had to remove the passport from this cover every single time',
#  'good quality skirt belt a little smaller for my waist',
#  'love this line it s so comfy star because the pocket aren t on the side',
#  'paid half the price here on amazon to replace the pair i lost love them',
#  'the stem separated from the jewel end very poor manufacture had to return for refund',
#  'my son love the punk rock look so every design bracelet and ring he have',
#  'i got these for my gf she love them perfect fit great print',
#  'i love these boot they are very comfortable and i could wear them all day',
#  'nice fit comfortable slip resistant the sol hows excessive wear after just a few week',
#  'practical gift for a friend with cancer look way more expensive than the actual cost',
#  'it is no where near tight the picture is misleading read the dimension before buying',
#  'look good on my baby and the color still look the same after multiple wash',
#  'paint peel instantly don t buy it it s comfortable but the material peeled on first wear',
#  'excellent pair of heel fit with my red dress very classy i recommended to all',
#  'lovely can see thru so don t recommend wearing outside unless using a beach coverup',
#  'good quality and great price wa purchased a a gift im happy with my purchase',
#  'barely make any light and it stopped working after about a half hour of use',
#  'i can t tell if they re comfortable or not because the cup size is too small',
#  'great shoe they fit larger than expected though i suggest going down a half size',
#  'nice for the price used for a tinker bell cosplay and it worked great',
#  'very comfortable i have other skechers with memory foam you can t beat it',
#  'great shirt fit well and ha sun protection which we need down in sunny florida',
#  'the pant are well made we like the cotton and wool fabric and the color',
#  'best cushioning running shoe i ever worn still too heavy for a fast pace though',
#  'nice suspender for casual or business use no problem after month of use',
#  'material is too thin and had a hole worn thru pocket within a couple month',
#  'cute but they are only going to be comfortable on someone with a narrow foot',
#  'this shirt fit great so comfy and look exactly like it doe in the picture',
#  'it cute but it wa very small upon arrival and after washing shrank teeny tiny',
#  'it s perfect wa a little wrinkled cuz of shipping but nothing hot steam won t solve',
#  'sleeve are a little big but cleaner fixed for very cheep now it look awesome',
#  'the medium ran a little larger than i like but it is wearable',
#  'wonderful pant great fit and comfortable i am weighing got a medium',
#  'this is not ll bean it a good shirt but not the brand i ordered',
#  'really cute shoe but very narrow ouch will keep them and get them stretched',
#  'love the shoe alittle tight but i think they will loosen a i wear them',
#  'a fine pair of denim jean that rival more expensive brand in fit and finish',
#  'super nice shirt did not expect it to be a nice a it is',
#  'i m glad she ordered the largest size available but it is a really cute shirt',
#  'fit slightly small other than that it is very very cute with vibrant color',
#  'way too small for my boyfriend s head it look like it would fit a child',
#  'i have pair of asics i love them this is my new favorite',
#  'wonderful bra i wear d and it make me perky lol comfortable delightful highly recommend',
#  'would have probably preferred a half size smaller for the shoe to fit more snug',
#  'cool wing they fit me well but i am a above average sized man',
#  'i really love these shoe they are comfortable and look great my husband wear them almost every day',
#  'very cute handbag i ha ere wearing it for a few day now',
#  'vibrant and practical great for an everyday day i will keep this bag in',
#  'have had several pair of this type of shoe and they fit great they are very comfortable',
#  'both pair fit great and have the wide width i normally wear a size and ordered a',
#  'not the size i expected but the quality is good the only reason i ordered this',
#  'great combination of low comfortable heel and an easy to walk in',
#  'adorable short for my son the quality is good and the fit is just right',
#  'it ha a weird defect i wear an xl in this shirt',
#  'plenty of room for all my thing and the comfortable fit is nice too',
#  'i ordered khaki and it wa way too small very good purchase nice bag',
#  'love it can easily be worn a a nightgown',
#  'this i got for me and it wa the best part of it the dress wa just what',
#  'i have bought ultra club shirt for year these are the first time i have been able to',
#  'this wa a gift for my wife and she loved it the only reason i gave it',
#  'my year old love this dress and she love it too she wear it in all the different',
#  'i wish crocs came in a larger size i ve had a lot of success with them',
#  'i ordered a small and it fit perfectly it is a little snug but not too tight',
#  'very cute although the print look a little sloppy on me the only reason i ordered',
#  'these are very comfortable they have the wide width which is perfect they are warm and',
#  'i ordered these originally a a gift and they fit perfectly i also have a large bust',
#  'color is a pictured abd it s a very comfortable shoe i have a wide foot',
#  'these boot are so comfortable and stretchy i ve worn them for a couple of hour',
#  'good for the money not a bad quality just not the quality that i wa looking for',
#  'very very comfortable top notching the only reason i gave it star',
#  'i have narrow foot and this shoe is perfect i will definitely be buying this shoe again',
#  'great to be able to find an item with the right fit these are the only one i',
#  'beautiful and comfortable my disappointment is that the strap are too small these are the only',
#  'bought a a gift for my wife and she love it she also love the way the',
#  'bought this for hubby it s a little large for him he normally wear a size',
#  'received product for a review i received the product in a timely manner and have not been disappointed',
#  'shoe were much smaller than expected the wide width is good but not for my foot',
#  'this top is one size small the wide width is too narrow the waist is too long',
#  'soft comfy fit well i m a d and these fit perfect i have a large bust',
#  'the large wa a perfect fit the wide knee part wa perfect the leg portion wa just right',
#  'great for the purpose i intended the quality is good but it s not a very strong one',
# ...
#  'smaller than desired but not a huge deal very good quality nice bag',
#  'fit perfectly on me i had previously tried that size at a store to confirm seems durable',
#  'had to quit wearing flip flop and these have been great and i can wear them all day',
#  'my man loved me in this we had an amazing night when i put this on for him',
#  'good fit adjustable strap the footbed cork get dark from perspiration from my foot not idea',
#  'loose fit and kind of heavy would be great if you wear them over thermal layer i guess',
#  'the silver is already coming off i ve only had it for a month bought it in june',
#  'i put in extra long sock for my search these thing only came about half way up my calf',
#  'these were for my daughter it s the fashion shoe of the moment great price on amazon',
#  'look great on my daughter fit very well the belt is a bit to long though',
#  'non steel toe fit well a long a you follow the sizing chart for a usa',
#  'beautiful boot but had to return them a the calf of my leg were to big for them',
#  'my friend just love this and it wa a good price very well made i must say',
#  'love these the perfect fit for my year old daughter who didn t want to take them off',
#  'i like it i bought two other bra from maidenform a good bra for the price',
#  'this sunglass is one of the best eyewear i have bought top quality and start',
#  'i bought it month ago and it is already stretched out but wa cute in the beginning',
#  'love these boot very classy look i will get a lot of wear with these boot',
#  'husband wa looking for work pant these were perfect navy is hard too find came quickly and neatly',
#  'keep great time it fit my arm and is stylish too i will definitely buy from them again',
#  'fun colorful sock for my grandson they go with lot of super hero and sport team shirt',
#  'comfy but not quite a good for my foot a converse i have a flat foot that s picky',
#  'shrunk considerably and don t wick sweat anywhere near a good a hiking sock but very comfortable',
#  'very much too small and fabric much thinner than i expected pretty color and includes a cute necklace',
#  'i have a blue pair and they are comfortable so i decided to order these in dark silver',
#  'good product pretty accurate and if definitely helped me keep my check in bag under to weight limit',
#  'typical pant i use left leg is twisted to the inside stitching is off somehow wearing them anyway',
#  'these short wash up great they boyfriend life in them nice material should probably order another pair',
#  'i love these boot so much i bought them for a halloween costume and i wear them everyday',
#  'he love this shirt it is cooler than the t shirt he usually wear and it travel well',
#  'super soft and fit great i wa pleasantly surprised that it fit so well and wa long enough',
#  'i returned because this shoe fit like a man way to big to be a woman s',
#  'i wa excited to see the quality sock these are my friend loved them big time',
#  'i bought this for my boyfriend it look great and seems to be durable and of good quality',
#  'nice hat but run very small wish i hadn t removed tag so i could have returned',
#  'i like these short a lot very nice and fit well not too short and not too long',
#  'they look very nice but the size is smaller than true size i have ordered one size larger',
#  'this a well constructed sandal except for the arch but overall it is a durable and fashionable sandal',
#  'i purchase the largest size available but it s still run small it did not meet my expectation',
#  'i wear a size and it fit fine i will keep it but i m',
#  'the t shirt is great the material is nice and the fabric is soft',
#  'i love clark i have a large head and these fit perfect they are warm and',
#  'this is the nd time that i have bought this watch i have a yellow wrist and',
#  'fit perfect loving it although it ha the wide width of a full size it s',
#  'bought this for my rd pair of the same pair i normally wear a size and',
#  'everything is fine but the material is too thick and thin for my liking the heel is just',
#  'great dress fit a expected not bulky at all very good quality',
#  'i bought these a size small i am usually a i ordered the',
#  'purchased these for my grandson he love them very comfortable',
#  'i think everyone wear scrub but i bought a size in a size in a size',
#  'i ve worn the bostonian brand for a couple year now and i still love them',
#  'x is about x large it s wide enough i normally wear a size and ordered',
#  'i love the dress but it ha a wide width which is a nice bonus',
#  'take a while due to the stretchy design but i will keep it for the next couple',
#  'the waist is completely different than the top the fit is a bit snug but not too',
#  'these are nice but rather small the wide width is too narrow',
#  'wow i love thus bag not bulky just very comfortable the only reason i',
#  'doe well on minor to moderate wear and the material are good i have worn this one twice',
#  'hat is decent felt hat but it is a little tight around the waist so i would recommend',
#  'perfect fit these are amazing perfect for me and very comfortable',
#  'super cute great deal well worth the money wife loved it',
#  'great looking shoe but produce a little bit of a popping noise when walking i have them in',
#  'very comfortable for sleeping in cute and very comfortable i love the style and the style',
#  'returned too small for my liking but very comfortable the only reason i ordered',
#  'perfect i got the navy blue and the navy blue is what i wanted the navy blue is',
#  'fit true to size and look great it is a little snug for my small size',
#  'flattering color fit and fabric are very nice the fit is nice the material is',
#  'this scrub pant elastic at the waist and wide knee i normally wear a size but ordered a',
#  'horrible you must be a grown man to order these shoe these are the only',
#  'great fit shoe hug the foot the wide toe box is a nice fit for the person with a',
#  'love this dress have it on a whole lot more i will wear it for a few hour',
#  'they always fit well i have a large head and these fit perfectly i have a large bust',
#  'very comfortable and stylish not bulky at all very good quality nice bag',
#  'based on measurement i got a size i normally wear a size',
#  'wow the chemical smell is not real the material are thick and clingy the material is',
#  'my last pair lasted several year the quality is good but the fit is just a little tight',
#  'they are cute but run small and narrow you can t wear these shoe all day order a size up',
#  'adorable and fit great my granddaughter is mo and this wa a good fit however glitter everywhere',
#  'great comfy boot usually wear a but had to exchange for a wa a bit to big',
#  'nice belt at a nice price fit well and the color is good i plan to buy additional color',
#  'i purchase it for my neice and she absolutely love it and that s what count',
#  'bought this for my wife to wear with a jingle chime necklace while she is pregnant she love it',
#  'the shoe look great and are comfortable but could use some arch support i can add those later',
#  'ordered a size up and it fit great good stretch holding up so far in the wash',
#  'cute little purse gave it to my sister a a gift perfect with jean or other casual outfit',
#  'my year old got a ton of use in the snow and mud never leaked no cold foot',
#  'omg these are so comfy and they pair well with dress or jean very happy with this purchase',
#  'im usually a size and it fit however a would be perfect love the style and look',
#  'these are the most awesome shoe i am going to order more color a soon a i can',
#  'it s a christmas gift so not really sure how it will fit but it look like the right size',
#  'i normally wear a size to with this shoe i wear a size',
#  'love these very comfortable perfect for between season when you re done with boot but not quite ready for sandles',
#  'this is a really little shirt certainly not a dress i m and the small wa too small',
#  'ordered half size larger due to recommendation couldn t be happier fit great and no sign of premature wear yet',
#  'cute style but not the best quality gemstone fall off easily and zipper on back of sandal get stuck',
#  'after the exchange i m satisfied the last pair looked counterfeit the logo wa off center but they look great now',
#  'sturdy shoe autistic daughter wore them everyday during the cold month she hate shoe but tolerated these',
#  'bought this for my daughter whose name is amber christmas ago she still wear it every day',
#  'the green in these is so pretty very eye catching the lever back is my favorite gorgeous',
#  'sadly not sewn well one pair fell apart a i put them on size wa fine just poor construction',
#  'not a sticky a other brand but otherwise are perfect nice to wear under a particularly thin bralette',
#  'always love s always fit great just like the original and they last for year won t buy any others',
#  'good quality fit good have bought several color in long sleeve and short looking for short sleeve white',
#  'very flat but cute and work for a narrow ish foot the strap fit well against the foot without gap',
#  'started using these at month with my girl who is petite and still using them a good purchase',
#  'above average heavy denim jean which is all i wear at a great price to me carhartt is special',
#  'nice cape it really made my costume complete dark green velvet with tie at neck one suze fit all',
#  'i love the light feature easy on and off and easy to read what more can you ask for',
#  'best bra ever follow the fitting guide and you can t go wrong they fit great are comfortable and last',
#  'love love this belt instantly my favorite one perfect fit cut to size and adjustable every pair of pant',
#  'this is just perfect the color work just great and it match with the color for the wedding',
#  'these lilac bloom legging are a pretty color very soft and comfortable will be getting more in different color',
#  'very pretty and great quality fabric and machine washable it wa given a a gift and they loved it',
#  'it s a product worth what it cost and the quality is great',
#  'i wa pleasantly surprised with this dress the material is thick and it is very comfortable',
#  'doe make a whining sound but i thought it wa a little too loud for the person who is',
#  'but also smaller than appeared on the picture not sure if it s just the sizing or if',
#  'need some time to break them in they look great the only reason i ordered the',
#  'hi that s wa my size and it fit fine very good quality',
#  'mine doe not have the material of the wide width i will return it',
#  'these bib are excellent they are stretchy and very comfortable i also like the',
#  'no complaint other than i m a professional with a comfortable fit these pant are a great',
#  'this is my nd pair of these and they are comfortable i also like the way the',
#  'just a little upset i had to return it very good quality nice bag very pretty',
#  'comfortable and daughter used it for a trip to the beach the only reason i gave',
#  'nice looking shoe comfortable but not bulky it is a little snug for my foot but',
#  'have pair of gloria vanderbilt lost weight and broke in',
#  'my son is racing all the time and the chain is too tight around his waist',
#  'fabric with wood like piece i love the look and feel of these shoe',
#  'my wife loved these so much she kept them very good quality nice bag very pretty',
#  'great sock don t have to break them in i will keep them for the next',
#  'pretty sporty and fit perfect i wear a size and it fit my little guy perfectly',
#  'this bra is very comfortable and ha the wide width i normally wear a size and ordered',
#  'i love how sleek and stylish it is it is a little snug around my hip but not too',
#  'this is the perfect vid for the wide width i will keep this for the next couple of',
#  'i have used this brand for a couple year now and i will keep my foot in this brand',
#  'very dissatisfied after wearing this pair of shoe for a week i have a hard time finding shoe',
#  'cute but wide at the waist the wide width is good enough',
#  'my husband say these are perfect the only problem is that they are kind of small',
#  'awesome passport holder i love the look of the design and the fit the bag is very',
#  'i bought this for a halloween costume and it wa just what i wanted it s a pretty dress',
#  'i recommend this product it is an amazing quality and comfortable fit i have a wide foot',
#  'the quality of the material is excellent and the material are thick enough to make wearing a shirt uncomfortable',
#  'i used the size chart and it wa fine i will keep this bag in my collection',
#  'love the material and the material is nice the fit is nice the heel is just a',
#  'i bought they were perfect the only problem is that they are very thin',
#  'these ripped the first time i wore them i wa a little surprised that the buckle broke',
#  'i purchased these boot for my wife and she love them she also love the way the toe',
#  'really nice quality and an excellent price i just wish it wa more of a size larger',
#  'authentic chuck taylor shoe they have the wide width and fit perfectly',
#  'it is lavender a stated it is a very comfortable fit the only reason i ordered',
#  'my new favorite go to pair of shoe i ve always wanted to have a pair of these',
#  'these are great shower shoe but the wide width make them uncomfortable these have a wide heel',
#  'perfect summer shoe go with everything the only problem is that it s a little too large',
#  'i love this earring simple classy and very comfortable the only reason i',
#  'i m so happy i didn t have to wear the knee pad i also have a wide',
#  'great shoe fit real gooooooood i wear a in these shoe',
#  'love them there size is perfect the only problem is that they are very thin',
#  'fit like i wouldn t expect it s a very comfortable shoe i have a wide',
#  'my daughter love these shoe they are comfortable and look great my daughter also love the way the',
#  'fit smaller than most used this to wear with a sweater i also have a large bust',
#  'my only complaint is that the strap were a bit long but very good quality will buy this brand again',
#  'i wa thinking they were more compression than they are they are nice and soft but they provide no compression',
#  'a little small but maybe due to i m a curvy gal def show em all beautiful dress all the same',
#  'this will replace my garment bag that i took on many trip i m so glad that it ha wheel',
#  'got these for a cruise joke during the formal meal worked a advertised but they are made for kid',
#  'nice looking slipper not that comfortable and started falling apart ended up buying a cheap slipper from the neighborhood mart',
#  'they fit perfect they look expensive they are the most confortable shoe that i had ever i love the design',
#  'this is much better than the first one i ordered it a really nice blzaer i would totally recommend it',
#  'i have bought at least ten pair and these are just wrong i strongly do not recommend this product sadly',
#  'work well so far and is quite pretty nice subtle deep burgundy purple band very easy to read face elegant',
#  'i could get this top on but the fabric wa stretched so much that you could see right through it',
#  'gift for a belated baptism year old this is a perfect size for her and know she ll enjoy it',
#  'fit good feel good so comfortable i forget i have them on i have no complaint at this time',
#  'needed an inexpensive belt for outdoor chore this is exactly what i wa looking for in both price and quality',
#  'arrived on time guess i have small wrist a little big but will wear it daily with a beaded bracelet',
#  'bought this to take with me to paris london my jewelry fit nice in there it s nicely made too classy',
#  'how could you not like the price and it turned out to be a good looking ring besides',
#  'i bought this a a gift she will surely know it s a gag gift it look incredibly cheap',
#  'now i wear fit flop sneaker sandal and slipper and my foot are happy maybe boot will be next',
#  'great slipper run to maybe a full size too long not to wide too long great leather soft comfortable',
#  ...]

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
words = []
for sent in corpus:
  sent_token = sent_tokenize(sent)
  #print(sent_token)
  for sent in sent_token:
    words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['granddaughter',
#   'love',
#   'it',
#   'bought',
#   'boxer',
#   'brief',
#   'for',
#   'my',
#   'daughter',
#   'and',
#   'she',
#   'loved',
#   'them'],
#  ['wish',
#   'the',
#   'strap',
#   'wa',
#   'more',
#   'of',
#   'wide',
#   'width',
#   'normally',
#   'wear',
#   'size',
#   'and',
#   'ordered'],
#  ['nice',
#   'thick',
#   'material',
#   'yr',
#   'old',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large',
#   'for'],
#  ['they',
#   'are',
#   'easy',
#   'to',
#   'use',
#   'and',
#   'have',
#   'the',
#   'wide',
#   'width',
#   'will',
#   'keep',
#   'them',
#   'for',
#   'the',
#   'summer',
#   'and',
#   'they'],
#  ['love',
#   'them',
#   'great',
#   'flippies',
#   'plus',
#   'they',
#   'fit',
#   'well',
#   'wife',
#   'loved',
#   'it'],
#  ['love',
#   'these',
#   'perfect',
#   'size',
#   'and',
#   'style',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'they',
#   'are',
#   'very',
#   'thin'],
#  ['uncomfortable',
#   'to',
#   'wear',
#   'because',
#   'of',
#   'that',
#   'bought',
#   'the',
#   'third',
#   'pair'],
#  ['really',
#   'love',
#   'this',
#   'shirt',
#   'the',
#   'fabric',
#   'is',
#   'thick',
#   'and',
#   'thick',
#   'and',
#   'the',
#   'material',
#   'is',
#   'durable'],
#  ['these',
#   'are',
#   'strong',
#   'and',
#   'not',
#   'overly',
#   'bulky',
#   'they',
#   'feel',
#   'comfortable',
#   'and',
#   'will',
#   'keep',
#   'my',
#   'foot',
#   'warm'],
#  ['fit',
#   'very',
#   'comfortable',
#   'bought',
#   'size',
#   'up',
#   'very',
#   'comfortable',
#   'love',
#   'the',
#   'style',
#   'and'],
#  ['got',
#   'this',
#   'for',
#   'my',
#   'grandson',
#   'wedding',
#   'the',
#   'quality',
#   'is',
#   'good',
#   'and',
#   'it',
#   'fit',
#   'my',
#   'son',
#   'well'],
#  ['work',
#   'well',
#   'enough',
#   'kind',
#   'of',
#   'look',
#   'like',
#   'the',
#   'picture',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['one',
#   'of',
#   'my',
#   'favorite',
#   'top',
#   'the',
#   'wide',
#   'brim',
#   'make',
#   'it',
#   'nice',
#   'fit',
#   'for',
#   'the',
#   'person',
#   'with',
#   'extra'],
#  ['great',
#   'buy',
#   'fit',
#   'great',
#   'quality',
#   'material',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large'],
#  ['need',
#   'to',
#   'be',
#   'size',
#   'small',
#   'the',
#   'wide',
#   'width',
#   'is',
#   'too',
#   'narrow',
#   'have',
#   'wide',
#   'foot',
#   'and'],
#  ['nice',
#   'but',
#   'very',
#   'very',
#   'long',
#   'not',
#   'an',
#   'easy',
#   'to',
#   'find',
#   'bra',
#   'but',
#   'it',
#   'fit',
#   'my',
#   'breast',
#   'well'],
#  ['great',
#   'quality',
#   'tee',
#   'and',
#   'my',
#   'daughter',
#   'love',
#   'it',
#   'very',
#   'comfortable',
#   'she',
#   'wear',
#   'size',
#   'and',
#   'the'],
#  ['love',
#   'love',
#   'this',
#   'shirt',
#   'and',
#   'received',
#   'many',
#   'compliment',
#   'it',
#   'is',
#   'thick',
#   'enough',
#   'to',
#   'cover',
#   'my',
#   'belly',
#   'button'],
#  ['great',
#   'for',
#   'the',
#   'price',
#   'you',
#   'will',
#   'be',
#   'sending',
#   'like',
#   'the',
#   'pant',
#   'and',
#   'com'],
#  ['excellent',
#   'product',
#   'good',
#   'workmanship',
#   'excellent',
#   'quality',
#   'not',
#   'too',
#   'thin',
#   'or',
#   'too',
#   'thin'],
#  ['the',
#   'only',
#   'dislike',
#   'is',
#   'they',
#   'are',
#   'little',
#   'wide',
#   'which',
#   'is',
#   'nice',
#   'bonus'],
#  ['new',
#   'balance',
#   'no',
#   'longer',
#   'go',
#   'under',
#   'my',
#   'arm',
#   'not',
#   'good',
#   'these',
#   'have',
#   'nice',
#   'look'],
#  ['just',
#   'like',
#   'the',
#   'one',
#   'bought',
#   'the',
#   'wide',
#   'width',
#   'is',
#   'good',
#   'enough',
#   'the',
#   'pocket',
#   'are',
#   'nice',
#   'and',
#   'the'],
#  ['awesome',
#   'shirt',
#   'with',
#   'perfect',
#   'fit',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'come',
#   'with',
#   'small',
#   'button',
#   'that',
#   'doesn'],
#  ['listened',
#   'to',
#   'everyone',
#   'else',
#   'and',
#   'it',
#   'ha',
#   'kept',
#   'me',
#   'cool',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'collection'],
#  ['sweet',
#   'jacket',
#   'dude',
#   'pack',
#   'are',
#   'little',
#   'tight',
#   'on',
#   'me',
#   'but',
#   'otherwise',
#   'they',
#   'are',
#   'great',
#   'very'],
#  ['arrived',
#   'on',
#   'time',
#   'great',
#   'shoe',
#   'and',
#   'will',
#   'be',
#   'buying',
#   'more',
#   'in',
#   'the',
#   'future'],
#  ['third',
#   'time',
#   'have',
#   'ordered',
#   'this',
#   'item',
#   'the',
#   'chain',
#   'is',
#   'too',
#   'large',
#   'the',
#   'chain',
#   'is',
#   'just',
#   'too'],
#  ['my',
#   'child',
#   'love',
#   'them',
#   'he',
#   'look',
#   'forward',
#   'to',
#   'wearing',
#   'them',
#   'love',
#   'it'],
#  ['my',
#   'son',
#   'loved',
#   'these',
#   'size',
#   'wa',
#   'little',
#   'small',
#   'but',
#   'will',
#   'keep',
#   'them'],
#  ['like',
#   'these',
#   'bra',
#   'very',
#   'much',
#   'they',
#   'are',
#   'comfortable',
#   'and',
#   'comfortable',
#   'am',
#   'year',
#   'old'],
#  ['lot',
#   'of',
#   'like',
#   'out',
#   'of',
#   'this',
#   'item',
#   'and',
#   'the',
#   'quality',
#   'is',
#   'great',
#   'nice',
#   'bag',
#   'very',
#   'pretty'],
#  ['nice',
#   'cross',
#   'body',
#   'love',
#   'the',
#   'material',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large',
#   'for'],
#  ['they',
#   'are',
#   'not',
#   'sized',
#   'the',
#   'way',
#   'they',
#   'should',
#   'be',
#   'and',
#   'will',
#   'keep',
#   'them',
#   'for',
#   'the',
#   'next',
#   'couple',
#   'of'],
#  ['very',
#   'comfortable',
#   'great',
#   'look',
#   'nice',
#   'quality',
#   'and',
#   'very',
#   'comfortable',
#   'also',
#   'the',
#   'heel',
#   'is'],
#  ['love',
#   'the',
#   'color',
#   'spacious',
#   'and',
#   'comfortable',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large',
#   'for'],
#  ['these',
#   'are',
#   'my',
#   'favorite',
#   'they',
#   'have',
#   'the',
#   'wide',
#   'width',
#   'and',
#   'fit',
#   'perfectly',
#   'they',
#   'are',
#   'warm',
#   'and'],
#  ['got',
#   'the',
#   'product',
#   'on',
#   'time',
#   'and',
#   'it',
#   'arrived',
#   'on',
#   'time',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'collection'],
#  ['nephew',
#   'love',
#   'the',
#   'color',
#   'and',
#   'look',
#   'great',
#   'he',
#   'is',
#   'and',
#   'wearing',
#   'size'],
#  ['these',
#   'are',
#   'dainty',
#   'and',
#   'beautiful',
#   'and',
#   'love',
#   'the',
#   'look',
#   'will',
#   'keep',
#   'them',
#   'for'],
#  ['little',
#   'smaller',
#   'that',
#   'expected',
#   'the',
#   'wide',
#   'width',
#   'is',
#   'good',
#   'but',
#   'not',
#   'for',
#   'me',
#   'very',
#   'pretty'],
#  ['this',
#   'maltese',
#   'cross',
#   'is',
#   'one',
#   'of',
#   'my',
#   'favorite',
#   'piece',
#   'of',
#   'jewelry',
#   'own',
#   'have',
#   'wide',
#   'foot'],
#  ['perfect',
#   'short',
#   'like',
#   'the',
#   'style',
#   'but',
#   'the',
#   'quality',
#   'is',
#   'just',
#   'what',
#   'wanted'],
#  ['cute',
#   'fabric',
#   'for',
#   'picture',
#   'slightly',
#   'small',
#   'the',
#   'wide',
#   'width',
#   'is',
#   'good',
#   'but',
#   'not',
#   'for',
#   'my',
#   'taste'],
#  ['good',
#   'item',
#   'pictured',
#   'not',
#   'an',
#   'easy',
#   'task',
#   'to',
#   'put',
#   'on',
#   'computer',
#   'but'],
#  ['so',
#   'cute',
#   'fit',
#   'really',
#   'well',
#   'and',
#   'have',
#   'kept',
#   'me',
#   'warm',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'house'],
#  ['the',
#   'quality',
#   'is',
#   'not',
#   'great',
#   'but',
#   'it',
#   'very',
#   'comfortable',
#   'shoe',
#   'have',
#   'wide',
#   'foot'],
#  ['it', 'is', 'georgous', 'blouse', 'wear', 'size', 'but', 'it', 'fit', 'my'],
#  ['delivered',
#   'fast',
#   'fit',
#   'well',
#   'look',
#   'good',
#   'and',
#   'feel',
#   'comfortable'],
#  ['very',
#   'cute',
#   'little',
#   'shoe',
#   'they',
#   'are',
#   'little',
#   'wide',
#   'on',
#   'me',
#   'but',
#   'otherwise',
#   'they',
#   'are',
#   'great',
#   'very',
#   'pretty'],
#  ['it',
#   'great',
#   'gift',
#   'my',
#   'daughter',
#   'love',
#   'it',
#   'very',
#   'comfortable',
#   'she',
#   'wear',
#   'it',
#   'everyday',
#   'and',
#   'ha'],
#  ['part',
#   'of',
#   'hip',
#   'hop',
#   'style',
#   'the',
#   'wide',
#   'knee',
#   'part',
#   'of',
#   'the',
#   'boot',
#   'is',
#   'just',
#   'little',
#   'too',
#   'high'],
#  ['very',
#   'cute',
#   'and',
#   'for',
#   'the',
#   'price',
#   'it',
#   'very',
#   'comfortable',
#   'fit',
#   'have',
#   'wide',
#   'foot',
#   'and'],
#  ['is',
#   'too',
#   'short',
#   'for',
#   'me',
#   'wear',
#   'an',
#   'xl',
#   'my',
#   'waist',
#   'is',
#   'just',
#   'tiny',
#   'bit'],
#  ['my',
#   'boy',
#   'love',
#   'these',
#   'they',
#   'fit',
#   'well',
#   'and',
#   'look',
#   'great',
#   'also',
#   'have',
#   'large',
#   'bust'],
#  ['great',
#   'pair',
#   'of',
#   'flip',
#   'flop',
#   'they',
#   'are',
#   'comfortable',
#   'and',
#   'comfortable',
#   'also',
#   'like',
#   'the',
#   'way'],
#  ['very',
#   'cute',
#   'just',
#   'wish',
#   'it',
#   'had',
#   'more',
#   'color',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['elastic',
#   'waste',
#   'help',
#   'when',
#   'sitting',
#   'on',
#   'bench',
#   'not',
#   'too',
#   'hot',
#   'or',
#   'too',
#   'cold'],
#  ['so',
#   'soft',
#   'and',
#   'comfortable',
#   'in',
#   'the',
#   'arm',
#   'and',
#   'leg',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'wardrobe'],
#  ['fit',
#   'well',
#   'and',
#   'easy',
#   'to',
#   'convert',
#   'with',
#   'semi',
#   'formal',
#   'wear'],
#  ['it', 'wa', 'gift', 'didn', 'get', 'any', 'feed', 'back'],
#  ['the',
#   'jean',
#   'fit',
#   'great',
#   'and',
#   'very',
#   'comfortable',
#   'also',
#   'good',
#   'price'],
#  ['the', 'color', 'of', 'this', 'scarf', 'are', 'beautiful', 'love', 'it'],
#  ['my',
#   'husband',
#   'love',
#   'these',
#   'they',
#   'will',
#   'look',
#   'great',
#   'on',
#   'him'],
#  ['great',
#   'product',
#   'and',
#   'very',
#   'comfortable',
#   'work',
#   'many',
#   'different',
#   'way'],
#  ['love', 'the', 'top', 'it', 'can', 'dress', 'up', 'and', 'down'],
#  ['nice', 'weight', 'to', 'fabric', 'not', 'flimsy', 'well', 'made'],
#  ['will', 'wear', 'this', 'watch', 'when', 'going', 'out', 'to', 'club'],
#  ['excelent', 'did', 'buy', 'one', 'inch', 'fit', 'very', 'well'],
#  ['year', 'old', 'daughter', 'loved', 'it', 'and', 'it', 'fit', 'wonderfully'],
#  ['son', 'wa', 'pleased', 'with', 'having', 'new', 'wallet'],
#  ['love', 'these', 'and', 'will', 'continue', 'to', 'order', 'them'],
#  ['could',
#   'use',
#   'nosepads',
#   'or',
#   'something',
#   'to',
#   'better',
#   'fit',
#   'kid',
#   'face'],
#  ['manufacturer',
#   'just',
#   'seem',
#   'to',
#   'keep',
#   'making',
#   'shoe',
#   'narrower',
#   'and',
#   'narrower'],
#  ['it', 'carhartt', 'what', 'can', 'say', 'great', 'product'],
#  ['no', 'buckle', 'for', 'the', 'shoe', 'so', 'it', 'always', 'pop', 'off'],
#  ['nice', 'shoe', 'fit', 'expected', 'not', 'for', 'all', 'day', 'comfort'],
#  ['nicely',
#   'made',
#   'thin',
#   'but',
#   'enough',
#   'cushion',
#   'to',
#   'make',
#   'slight',
#   'impact'],
#  ['finally', 'calvin', 'klein', 'polo', 'for', 'big', 'men', 'nice', 'fit'],
#  ['my',
#   'husband',
#   'love',
#   'these',
#   'they',
#   'are',
#   'comfortable',
#   'and',
#   'really',
#   'nice'],
#  ['love',
#   'these',
#   'perfect',
#   'fit',
#   'not',
#   'too',
#   'stretchy',
#   'great',
#   'color'],
#  ['great', 'for', 'the', 'girl', 'and', 'bought', 'small'],
#  ['bought', 'for', 'my', 'wife', 'she', 'love', 'them'],
#  ['nice', 'robe', 'but', 'returned', 'it', 'cause', 'it', 'wa', 'too', 'big'],
#  ['so', 'stylish', 'for', 'the', 'little', 'diva', 'in', 'your', 'life'],
#  ['this',
#   'costume',
#   'fit',
#   'perfectly',
#   'and',
#   'got',
#   'ton',
#   'of',
#   'compliment'],
#  ['didn', 'have', 'rainy', 'day', 'yet', 'but', 'love', 'it', 'already'],
#  ['very',
#   'soft',
#   'fabric',
#   'no',
#   'much',
#   'support',
#   'but',
#   'nice',
#   'for',
#   'seleeping'],
#  ['levi', 'are', 'great', 'very', 'comfortable', 'keep', 'my', 'arse', 'warm'],
#  ['comfortable',
#   'great',
#   'support',
#   'yet',
#   'still',
#   'pretty',
#   'and',
#   'feminine',
#   'love',
#   'it'],
#  ['easy',
#   'dress',
#   'to',
#   'slip',
#   'on',
#   'form',
#   'fitted',
#   'thin',
#   'material',
#   'summer',
#   'material'],
#  ['bought', 'them', 'for', 'my', 'daughter', 'she', 'is', 'tennis', 'beginer'],
#  ['loved',
#   'those',
#   'but',
#   'they',
#   'were',
#   'worn',
#   'out',
#   'after',
#   'one',
#   'year'],
#  ['tiny',
#   'bit',
#   'large',
#   'but',
#   'accommodates',
#   'thicker',
#   'sock',
#   'just',
#   'fine'],
#  ['beautiful',
#   'dress',
#   'it',
#   'fit',
#   'perfect',
#   'and',
#   'love',
#   'love',
#   'the',
#   'pocket'],
#  ['love', 'the', 'sanuk', 'brand', 'shoe', 'they', 'are', 'the', 'best'],
#  ['am', 'very', 'happy', 'with', 'my', 'michael', 'korda', 'shoulder', 'bag'],
#  ['great', 'looking', 'jacket', 'love', 'that', 'it', 'came', 'with', 'hat'],
#  ['it', 'will', 'take', 'while', 'to', 'get', 'these', 'broken', 'in'],
#  ['beautiful',
#   'vibrant',
#   'skirt',
#   'but',
#   'snug',
#   'at',
#   'the',
#   'waist',
#   'size',
#   'up'],
#  ['too', 'small', 'and', 'see', 'through', 'gave', 'them', 'to', 'goodwill'],
#  ['the', 'shoe', 'is', 'larger', 'then', 'the', 'one', 'currently', 'have'],
#  ['not', 'quite', 'what', 'expected', 'but', 'it', 'will', 'get', 'used'],
#  ['nice', 'warm', 'mitten', 'untill', 'lost', 'one', 'of', 'them', 'lol'],
#  ['my',
#   'son',
#   'love',
#   'these',
#   'sneaker',
#   'wear',
#   'them',
#   'all',
#   'the',
#   'time'],
#  ['doe', 'not', 'have', 'the', 'support', 'thought', 'it', 'would', 'have'],
#  ['perfect', 'in', 'every', 'way', 'just', 'what', 'wa', 'looking', 'for'],
#  ['love', 'the', 'vest', 'over', 'the', 'onesie', 'such', 'cute', 'outfit'],
#  ['bought', 'them', 'for', 'my', 'mom', 'and', 'she', 'like', 'them'],
#  ['wrangler',
#   'jean',
#   'are',
#   'the',
#   'best',
#   'great',
#   'fit',
#   'and',
#   'price',
#   'cheer'],
#  ['we', 'love', 'these', 'shoe', 'my', 'kid', 'wear', 'them', 'everywhere'],
#  ['somewhat', 'to', 'large', 'for', 'me', 'but', 'they', 'are', 'ok'],
#  ['go',
#   'with',
#   'your',
#   'gut',
#   'for',
#   'sizing',
#   'you',
#   'll',
#   'be',
#   'better',
#   'off'],
#  ['had', 'to', 'hem', 'the', 'cuff', 'wa', 'in', 'to', 'long'],
#  ['love',
#   'love',
#   'love',
#   'these',
#   'will',
#   'be',
#   'buying',
#   'more',
#   'again',
#   'soon'],
#  ['they', 'fit', 'little', 'loose', 'but', 'still', 'like', 'them'],
#  ['alot',
#   'of',
#   'snap',
#   'to',
#   'attach',
#   'doe',
#   'the',
#   'job',
#   'once',
#   'buttoned',
#   'up'],
#  ['exactly', 'described', 'and', 'just', 'what', 'wa', 'looking', 'for'],
#  ['these',
#   'are',
#   'very',
#   'comfortable',
#   'they',
#   'have',
#   'the',
#   'wide',
#   'width',
#   'which',
#   'is',
#   'perfect',
#   'they',
#   'are',
#   'warm',
#   'and'],
#  ['great',
#   'levi',
#   'my',
#   'daughter',
#   'love',
#   'them',
#   've',
#   'had',
#   'her',
#   'for',
#   'couple'],
#  ['it',
#   'work',
#   'it',
#   'look',
#   'like',
#   'real',
#   'watch',
#   'it',
#   'is',
#   'little',
#   'snug',
#   'but',
#   'not',
#   'too',
#   'tight'],
#  ['son',
#   'is',
#   'ok',
#   'with',
#   'these',
#   'but',
#   'they',
#   'are',
#   'little',
#   'tight',
#   'around',
#   'the',
#   'waist',
#   'so',
#   'not'],
#  ['need',
#   'to',
#   'be',
#   'broken',
#   'in',
#   'but',
#   'am',
#   'very',
#   'pleased',
#   'with',
#   'it',
#   'nice',
#   'bag',
#   'very',
#   'pretty'],
#  ['very',
#   'comfortable',
#   'slightly',
#   'larger',
#   'than',
#   'expected',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large',
#   'for'],
#  ['always',
#   'asics',
#   'delivers',
#   'they',
#   'have',
#   'the',
#   'quality',
#   'and',
#   'comfort',
#   'of',
#   'uggs'],
#  ['bought',
#   'for',
#   'gift',
#   'and',
#   'it',
#   'arrived',
#   'on',
#   'time',
#   'will',
#   'keep',
#   'it',
#   'for',
#   'myself',
#   'and',
#   'my',
#   'husband'],
#  ['the',
#   'hat',
#   'wa',
#   'smashed',
#   'on',
#   'the',
#   'side',
#   'and',
#   'the',
#   'chain',
#   'broke',
#   'the',
#   'only',
#   'reason',
#   'ordered',
#   'this'],
#  ['good',
#   'value',
#   'and',
#   'quality',
#   'professional',
#   'with',
#   'lot',
#   'of',
#   'work',
#   'these',
#   'pant',
#   'are',
#   'awesome'],
#  ['it',
#   'very',
#   'cute',
#   'outfit',
#   'but',
#   'the',
#   'quality',
#   'is',
#   'just',
#   'not',
#   'good'],
#  ['wanted',
#   'the',
#   'pant',
#   'in',
#   'moucha',
#   'color',
#   'the',
#   'quality',
#   'is',
#   'good',
#   'but',
#   'the',
#   'waist',
#   'is',
#   'little'],
#  ['false',
#   'advertising',
#   'there',
#   'is',
#   'no',
#   'price',
#   'buy',
#   'it',
#   'will',
#   'keep',
#   'my',
#   'money',
#   'very',
#   'pretty'],
#  ['nice',
#   'lightweight',
#   'shirt',
#   'look',
#   'good',
#   'and',
#   'ha',
#   'the',
#   'wide',
#   'brim',
#   'will',
#   'keep',
#   'it'],
#  ['they',
#   'look',
#   'different',
#   'in',
#   'person',
#   'but',
#   'the',
#   'quality',
#   'is',
#   'just',
#   'right',
#   'the',
#   'only',
#   'reason',
#   'ordered',
#   'the'],
#  ['too',
#   'short',
#   'for',
#   'my',
#   'lip',
#   'but',
#   'thought',
#   'it',
#   'would',
#   'fit',
#   'better',
#   'it',
#   'pretty',
#   'good'],
#  ['for',
#   'size',
#   'medium',
#   'they',
#   'are',
#   'little',
#   'tight',
#   'on',
#   'me',
#   'but',
#   'otherwise',
#   'they',
#   'are',
#   'great',
#   'very',
#   'pretty'],
#  ['material',
#   'is',
#   'soft',
#   'and',
#   'conforms',
#   'to',
#   'my',
#   'body',
#   'it',
#   'is',
#   'little',
#   'snug',
#   'for',
#   'my',
#   'small',
#   'size'],
#  ['decent',
#   'quality',
#   'need',
#   'more',
#   'garter',
#   'belt',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too'],
#  ['work',
#   'perfect',
#   'spotted',
#   'my',
#   'luggage',
#   'instantly',
#   'love',
#   'the',
#   'look',
#   'and',
#   'feel',
#   'of',
#   'it'],
#  ['very',
#   'good',
#   'support',
#   'in',
#   'small',
#   'size',
#   'the',
#   'material',
#   'are',
#   'thick',
#   'enough',
#   'to',
#   'make',
#   'it',
#   'comfortable',
#   'to',
#   'wear'],
#  ['belt',
#   'is',
#   'sewn',
#   'in',
#   'but',
#   'it',
#   'ha',
#   'the',
#   'wide',
#   'width',
#   'normally',
#   'wear',
#   'size',
#   'and'],
#  ['fit',
#   'fine',
#   'and',
#   'the',
#   'grandson',
#   'look',
#   'cute',
#   'in',
#   'it',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['this',
#   'kimono',
#   'feel',
#   'damp',
#   'look',
#   'cheap',
#   'but',
#   'it',
#   'is',
#   'worth',
#   'it'],
#  ['got',
#   'this',
#   'for',
#   'my',
#   'boyfriend',
#   'and',
#   'he',
#   'love',
#   'it',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag',
#   'very',
#   'pretty'],
#  ['first',
#   'cadet',
#   'hat',
#   'that',
#   'ever',
#   'stood',
#   'up',
#   'to',
#   'the',
#   'test',
#   'will',
#   'be',
#   'purchasing',
#   'more',
#   'in',
#   'other',
#   'color'],
#  ['love',
#   'how',
#   'stylish',
#   'it',
#   'is',
#   'the',
#   'wide',
#   'width',
#   'make',
#   'it',
#   'nice',
#   'fit',
#   'for',
#   'person',
#   'with'],
#  ['perfect',
#   'would',
#   'recommend',
#   'this',
#   'product',
#   'great',
#   'quality',
#   'and',
#   'comfortable',
#   'fit',
#   'have',
#   'wide',
#   'foot'],
#  ['love',
#   'this',
#   'made',
#   'well',
#   'flow',
#   'look',
#   'good',
#   'and',
#   'fit',
#   'well'],
#  ['these',
#   'were',
#   'what',
#   'wanted',
#   'they',
#   'are',
#   'wide',
#   'and',
#   'comfortable',
#   'also',
#   'like',
#   'the',
#   'way',
#   'the'],
#  ['the',
#   'folding',
#   'plastic',
#   'seems',
#   'to',
#   'be',
#   'nice',
#   'quality',
#   'material',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'collection'],
#  ['dress',
#   'is',
#   'adorable',
#   'will',
#   'definitely',
#   'be',
#   'ordering',
#   'more',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['great',
#   'hat',
#   'the',
#   'price',
#   'wa',
#   'right',
#   'and',
#   'the',
#   'quality',
#   'is',
#   'good',
#   'the',
#   'only',
#   'reason',
#   'ordered'],
#  ['seed',
#   'my',
#   'wife',
#   'love',
#   'them',
#   'love',
#   'the',
#   'look',
#   'and',
#   'fit',
#   'of',
#   'these',
#   'shoe'],
#  ['my',
#   'grandson',
#   'wore',
#   'these',
#   'for',
#   'couple',
#   'of',
#   'year',
#   'and',
#   'they',
#   'fit',
#   'perfectly',
#   'he',
#   'love',
#   'the',
#   'way',
#   'they',
#   'look'],
#  ['so',
#   'pretty',
#   'too',
#   'short',
#   'and',
#   'not',
#   'stretchy',
#   'at',
#   'all',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'wardrobe'],
#  ['too',
#   'small',
#   'they',
#   'seem',
#   'to',
#   'be',
#   'well',
#   'made',
#   'and',
#   'comfortable',
#   'also',
#   'like',
#   'the',
#   'way',
#   'the'],
#  ['the',
#   'extra',
#   'padding',
#   'in',
#   'the',
#   'back',
#   'of',
#   'the',
#   'boot',
#   'is',
#   'just',
#   'what',
#   'needed',
#   'for',
#   'my',
#   'foot'],
#  ['the',
#   'product',
#   'fit',
#   'expected',
#   'and',
#   'look',
#   'great',
#   'with',
#   'jean',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'wardrobe'],
#  ['great',
#   'bag',
#   'exactly',
#   'described',
#   'love',
#   'the',
#   'color',
#   'also',
#   'the',
#   'zipper',
#   'is',
#   'awesome'],
#  ['thank',
#   'you',
#   'item',
#   'wa',
#   'described',
#   'great',
#   'quality',
#   'and',
#   'comfortable',
#   'fit',
#   'have',
#   'wide',
#   'foot'],
#  ['if',
#   'it',
#   'hold',
#   'up',
#   'reasonably',
#   'it',
#   'should',
#   'be',
#   'very',
#   'comfortable',
#   'for',
#   'lot',
#   'of',
#   'use',
#   'very',
#   'pretty'],
#  ['now',
#   'im',
#   'ready',
#   'for',
#   'the',
#   'weekend',
#   'the',
#   'quality',
#   'is',
#   'good',
#   'but',
#   'it',
#   'doesnt',
#   'fit',
#   'my',
#   'small',
#   'baby'],
#  ['they',
#   're',
#   'kinda',
#   'cheap',
#   'and',
#   'easy',
#   'to',
#   'break',
#   'in',
#   'but',
#   'they',
#   're',
#   'nice',
#   'fit',
#   'for',
#   'the',
#   'person',
#   'who'],
#  ['good',
#   'fit',
#   'love',
#   'having',
#   'my',
#   'go',
#   'to',
#   'shoe',
#   'these',
#   'fit',
#   'perfect'],
#  ['this',
#   'is',
#   'very',
#   'comfortable',
#   'soft',
#   'and',
#   'lightweight',
#   'coat',
#   'will',
#   'be',
#   'purchasing',
#   'more',
#   'in',
#   'other',
#   'color'],
#  ['run',
#   'about',
#   'size',
#   'too',
#   'small',
#   'the',
#   'wide',
#   'width',
#   'is',
#   'too',
#   'narrow'],
#  ['love',
#   'vanity',
#   'fair',
#   'bra',
#   'and',
#   'love',
#   'the',
#   'look',
#   'will',
#   'keep',
#   'my',
#   'purse',
#   'in',
#   'the',
#   'drawer'],
#  ['it',
#   'fit',
#   'well',
#   'the',
#   'heel',
#   'is',
#   'little',
#   'wide',
#   'and',
#   'the',
#   'foot',
#   'bed',
#   'is',
#   'little',
#   'too',
#   'big'],
#  ['warm',
#   'great',
#   'color',
#   'for',
#   'teen',
#   'and',
#   'tweens',
#   'wife',
#   'loved',
#   'it'],
#  ['very',
#   'nice',
#   'bra',
#   'only',
#   'complaint',
#   'is',
#   'the',
#   'top',
#   'part',
#   'is',
#   'little',
#   'tight',
#   'around',
#   'my',
#   'breast',
#   'very',
#   'pretty'],
#  ['these',
#   'earring',
#   'green',
#   'are',
#   'elegant',
#   'and',
#   'sparkly',
#   'the',
#   'pink',
#   'is',
#   'lovely',
#   'color',
#   'and'],
#  ['it',
#   'nice',
#   'set',
#   'for',
#   'costume',
#   'but',
#   'the',
#   'fabric',
#   'is',
#   'little',
#   'tighter',
#   'than',
#   'expected'],
#  ['bought',
#   'for',
#   'guy',
#   'friend',
#   'and',
#   'he',
#   'liked',
#   'the',
#   'look',
#   'he',
#   'also',
#   'liked',
#   'that',
#   'it',
#   'wa'],
#  ['my',
#   'daughter',
#   'love',
#   'these',
#   'super',
#   'soft',
#   'and',
#   'confortable',
#   'great',
#   'quality',
#   'the',
#   'only',
#   'reason',
#   'ordered'],
#  ['fit', 'little', 'tight', 'but', 'think', 'theyll', 'break', 'in', 'nicely'],
#  ['this',
#   'is',
#   'high',
#   'quality',
#   'product',
#   'great',
#   'fit',
#   'great',
#   'price',
#   'well'],
#  ['love',
#   'these',
#   'fit',
#   'perfect',
#   'and',
#   'are',
#   'comfy',
#   'and',
#   'look',
#   'super',
#   'cute'],
#  ['fit',
#   'right',
#   'and',
#   'is',
#   'real',
#   'fruit',
#   'of',
#   'the',
#   'loom',
#   'product'],
#  ['this',
#   'gown',
#   'is',
#   'sheer',
#   'it',
#   'is',
#   'beautiful',
#   'and',
#   'very',
#   'comfortable'],
#  ['these',
#   'are',
#   'some',
#   'beautiful',
#   'comfortable',
#   'shoe',
#   'glad',
#   'found',
#   'them'],
#  ['wear', 'size', 'and', 'these', 'were', 'true', 'to', 'size'],
#  ['these',
#   'are',
#   'way',
#   'too',
#   'small',
#   'and',
#   'are',
#   'sized',
#   'like',
#   'childrens',
#   'underwear'],
#  ['amazing',
#   'love',
#   'it',
#   'look',
#   'adorable',
#   'on',
#   'my',
#   'navy',
#   'blue',
#   'bag'],
#  ['is',
#   'even',
#   'more',
#   'than',
#   'expected',
#   'quality',
#   'appears',
#   'to',
#   'be',
#   'excellent'],
#  ['my',
#   'granddaughter',
#   'loved',
#   'it',
#   'little',
#   'wait',
#   'but',
#   'she',
#   'loved',
#   'it'],
#  ['child',
#   'ha',
#   'mark',
#   'on',
#   'her',
#   'foot',
#   'after',
#   'wearing',
#   'for',
#   'hour'],
#  ['adorable',
#   'bought',
#   'for',
#   'my',
#   'daughter',
#   'who',
#   'is',
#   'fit',
#   'her',
#   'perfectly'],
#  ['my',
#   'son',
#   'love',
#   'it',
#   'look',
#   'awesome',
#   'fast',
#   'service',
#   'great',
#   'seller'],
#  ['great',
#   'shoe',
#   'best',
#   'fit',
#   'they',
#   'last',
#   'about',
#   'year',
#   'before',
#   'fading'],
#  ['really',
#   'love',
#   'this',
#   'purchase',
#   'so',
#   'comfortable',
#   'and',
#   'wash',
#   'well',
#   'great',
#   'buy'],
#  ['this', 'is', 'my', 'third', 'pair', 'and', 'could', 'not', 'be', 'happier'],
#  ['embroidery',
#   'is',
#   'stiff',
#   'but',
#   'doesn',
#   'bother',
#   'me',
#   'cute',
#   'for',
#   'the',
#   'price'],
#  ['came',
#   'at',
#   'expected',
#   'time',
#   'great',
#   'fit',
#   'and',
#   'love',
#   'the',
#   'style'],
#  ['needed', 'another', 'navy', 'shoe', 'like', 'the', 'touch', 'of', 'red'],
#  ['great', 'jean', 'skirt', 'soft', 'and', 'comfortable', 'just', 'fit'],
#  ['well',
#   'made',
#   'shirt',
#   'very',
#   'durable',
#   'soft',
#   'and',
#   'high',
#   'quality'],
#  ['exactly',
#   'what',
#   'wanted',
#   'received',
#   'quickly',
#   'fair',
#   'pricing',
#   'good',
#   'customer',
#   'service'],
#  ['purposely',
#   'ordered',
#   'larger',
#   'size',
#   'and',
#   'these',
#   'jean',
#   'were',
#   'tight'],
#  ['really', 'liked', 'that', 'you', 'carry', 'big', 'size'],
#  ['hat',
#   'is',
#   'nice',
#   'very',
#   'good',
#   'quality',
#   'and',
#   'is',
#   'shipped',
#   'well',
#   'also'],
#  ['the',
#   'landau',
#   'scrub',
#   'are',
#   'the',
#   'most',
#   'comfortable',
#   'scrub',
#   'that',
#   'have'],
#  ['great',
#   'shoe',
#   'would',
#   'definitely',
#   'buy',
#   'again',
#   'big',
#   'fan',
#   'of',
#   'softspots'],
#  ['doe',
#   'not',
#   'stick',
#   'well',
#   'at',
#   'all',
#   'had',
#   'to',
#   'add',
#   'extra',
#   'glue'],
#  ['thankful',
#   'for',
#   'easy',
#   'return',
#   'on',
#   'amazon',
#   'these',
#   'were',
#   'too',
#   'small'],
#  ['love',
#   'love',
#   'love',
#   'it',
#   'fit',
#   'exactly',
#   'expected',
#   'and',
#   'is',
#   'comfortable'],
#  ['doe',
#   'for',
#   'me',
#   'what',
#   'expected',
#   'plenty',
#   'of',
#   'room',
#   'carry',
#   'daily',
#   'perfect',
#   'quality'],
#  ['these',
#   'keen',
#   'are',
#   'very',
#   'comfortable',
#   'the',
#   'color',
#   'go',
#   'well',
#   'with',
#   'everything'],
#  ['have', 'bought', 'multiple', 'color', 'of', 'this', 'pant', 'love', 'it'],
#  ['strap',
#   'were',
#   'extremely',
#   'tight',
#   'which',
#   'wa',
#   'the',
#   'reason',
#   'they',
#   'were',
#   'returned'],
#  ['my',
#   'husband',
#   'is',
#   'very',
#   'picky',
#   'about',
#   'wallet',
#   'this',
#   'one',
#   'he',
#   'love'],
#  ['very',
#   'nice',
#   'shoe',
#   'feel',
#   'nice',
#   'on',
#   'foot',
#   'and',
#   'fit',
#   'perfect'],
#  ['say', 'size', 'whatever', 'not', 'for', 'that', 'for', 'sure'],
#  ['not',
#   'to',
#   'tight',
#   'with',
#   'the',
#   'elastic',
#   'but',
#   'very',
#   'supportive',
#   'and',
#   'comfortable'],
#  ['one',
#   'of',
#   'the',
#   'shoe',
#   'doesn',
#   'light',
#   'up',
#   'like',
#   'it',
#   'supposed',
#   'to'],
#  ['disappointed',
#   'when',
#   'got',
#   'it',
#   'photo',
#   'over',
#   'exsentuates',
#   'the',
#   'actual',
#   'ring'],
#  ['love', 'merrel', 'just', 'will', 'could', 'buy', 'more'],
#  ['great', 'quality', 'fit', 'good', 'very', 'warm', 'and', 'comfy'],
#  ['been', 'wearing', 'since', 'the', 'late', 'can', 'beat', 'them'],
#  ['the',
#   'quality',
#   'is',
#   'good',
#   'and',
#   'like',
#   'the',
#   'soft',
#   'gray',
#   'color'],
#  ['very',
#   'nice',
#   'vest',
#   'sized',
#   'perfect',
#   'very',
#   'comfortable',
#   'carhartt',
#   'quality',
#   'exoected'],
#  ['look',
#   'great',
#   'on',
#   'the',
#   'gf',
#   'provides',
#   'lift',
#   'and',
#   'oh',
#   'so',
#   'sexy'],
#  ['saved',
#   'me',
#   'from',
#   'sun',
#   'damage',
#   'in',
#   'hawaii',
#   'fit',
#   'great',
#   'look',
#   'nice'],
#  ['work', 'neck', 'gator', 'but', 'hood', 'doe', 'not', 'cover', 'forhead'],
#  ['bought',
#   'them',
#   'for',
#   'my',
#   'daughter',
#   'who',
#   'love',
#   'tom',
#   'they',
#   'fit',
#   'perfectly'],
#  ['very', 'nice', 'bra', 'good', 'fit', 'comfortable', 'good', 'price'],
#  ['the',
#   'snake',
#   'head',
#   'wa',
#   'little',
#   'cheesy',
#   'but',
#   'overall',
#   'it',
#   'nice'],
#  ['best', 'support', 'for', 'size', 'belonging', 'to', 'senior', 'citizen'],
#  ['beautiful',
#   'and',
#   'comfortable',
#   'just',
#   'expected',
#   'it',
#   'from',
#   'cole',
#   'haan'],
#  ['love', 'this', 'top', 'so', 'comfortable', 'and', 'wash', 'well'],
#  ['precious',
#   'hat',
#   'southern',
#   'classic',
#   'not',
#   'an',
#   'everyday',
#   'hat',
#   'but',
#   'will',
#   'keep',
#   'it'],
#  ['very',
#   'nice',
#   'black',
#   'white',
#   'slingback',
#   'pump',
#   'and',
#   'it',
#   'very',
#   'comfortable',
#   'fit'],
#  ['it',
#   'great',
#   'product',
#   'but',
#   'it',
#   'ha',
#   'wide',
#   'width',
#   'normally',
#   'wear',
#   'size',
#   'but',
#   'ordered'],
#  ['very',
#   'comfortable',
#   'true',
#   'to',
#   'size',
#   'not',
#   'bulky',
#   'at',
#   'all',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['this',
#   'fit',
#   'well',
#   'but',
#   'find',
#   'it',
#   'too',
#   'small',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag',
#   'very',
#   'pretty'],
#  ['the',
#   'strap',
#   'fell',
#   'on',
#   'on',
#   'the',
#   'side',
#   'and',
#   'the',
#   'chain',
#   'broke',
#   'the',
#   'bag',
#   'is',
#   'bit',
#   'small'],
#  ['seems',
#   'sturdy',
#   'carry',
#   'passport',
#   'id',
#   'and',
#   'cell',
#   'phone',
#   'ha',
#   'lot',
#   'of'],
#  ['love',
#   'these',
#   'ring',
#   'best',
#   'ring',
#   'have',
#   'ever',
#   'owned',
#   'very',
#   'good',
#   'quality'],
#  ['gave',
#   'them',
#   'away',
#   'not',
#   'up',
#   'for',
#   'an',
#   'entire',
#   'year',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['comfortable',
#   'and',
#   'stretchy',
#   'the',
#   'only',
#   'issue',
#   'have',
#   'with',
#   'the',
#   'shoe',
#   'is',
#   'that',
#   'they',
#   'are',
#   'little'],
#  ['very',
#   'comfortable',
#   'and',
#   'it',
#   'fit',
#   'perfect',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large',
#   'for',
#   'me'],
#  ['ordered',
#   'xl',
#   'and',
#   'are',
#   'little',
#   'tight',
#   'but',
#   'they',
#   'are',
#   'good',
#   'enough'],
#  ['very',
#   'cute',
#   'may',
#   'not',
#   'fit',
#   'expected',
#   'but',
#   'very',
#   'comfortable',
#   'the',
#   'only',
#   'reason',
#   'ordered'],
#  ['believe',
#   'that',
#   'go',
#   'to',
#   'the',
#   'gym',
#   'will',
#   'need',
#   'to',
#   'make',
#   'sure',
#   'get',
#   'the',
#   'correct'],
#  ['love',
#   'the',
#   'quality',
#   'exactly',
#   'what',
#   'expected',
#   'and',
#   'the',
#   'price',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'collection'],
#  ['this',
#   'is',
#   'so',
#   'cute',
#   'and',
#   'look',
#   'great',
#   'the',
#   'material',
#   'are',
#   'thick',
#   'enough',
#   'to',
#   'make',
#   'it',
#   'comfortable',
#   'but',
#   'not',
#   'too'],
#  ['love',
#   'these',
#   'shoe',
#   'have',
#   'an',
#   'xl',
#   'and',
#   'they',
#   'fit',
#   'perfectly',
#   'also',
#   'have',
#   'large',
#   'foot'],
#  ['this',
#   'shirt',
#   'wa',
#   'the',
#   'true',
#   'go',
#   'to',
#   'for',
#   'the',
#   'night',
#   'will',
#   'be',
#   'purchasing',
#   'more',
#   'in',
#   'other',
#   'color'],
#  ['wearing',
#   'the',
#   'dress',
#   'go',
#   'to',
#   'the',
#   'gym',
#   'wa',
#   'surprised',
#   'by',
#   'how',
#   'well',
#   'the',
#   'material',
#   'fit'],
#  ['very',
#   'elegant',
#   'looking',
#   'shoe',
#   'nice',
#   'material',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large'],
#  ['nice', 'elegant', 'watch'],
#  ['very',
#   'pretty',
#   'and',
#   'feel',
#   'great',
#   'love',
#   'the',
#   'look',
#   'and',
#   'fit',
#   'of',
#   'this',
#   'bra'],
#  ['purchase',
#   'for',
#   'friend',
#   'who',
#   'is',
#   'an',
#   'avid',
#   'tennis',
#   'player',
#   'will',
#   'be',
#   'purchasing',
#   'more',
#   'in',
#   'other',
#   'color'],
#  ['very',
#   'nice',
#   'and',
#   'comfortable',
#   'definitely',
#   'recommend',
#   'great',
#   'quality',
#   'and',
#   'comfortable',
#   'fit',
#   'have',
#   'wide',
#   'foot'],
#  ['average',
#   'quality',
#   'doubt',
#   'it',
#   'will',
#   'last',
#   'long',
#   'overall',
#   'good',
#   'purchase',
#   'nice',
#   'bag'],
#  ['like', 'them', 'though', 'they', 're', 'little', 'short', 'and', 'weigh'],
#  ['liked',
#   'these',
#   'so',
#   'much',
#   'bought',
#   'second',
#   'pair',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['beautiful',
#   'lovely',
#   'quality',
#   'and',
#   'look',
#   'great',
#   'great',
#   'quality',
#   'for',
#   'the',
#   'price',
#   'am'],
#  ['asics',
#   'always',
#   'fit',
#   'perfectly',
#   'this',
#   'is',
#   'great',
#   'quality',
#   'and',
#   'comfortable',
#   'fit',
#   'have',
#   'wide'],
#  ['nice',
#   'flip',
#   'flop',
#   'but',
#   'they',
#   'are',
#   'little',
#   'wide',
#   'on',
#   'me',
#   'nice',
#   'for',
#   'the',
#   'price'],
#  ['amazing',
#   'sock',
#   'well',
#   'made',
#   'and',
#   'look',
#   'good',
#   'too',
#   've',
#   'worn',
#   'them',
#   'for',
#   'couple',
#   'of',
#   'hour'],
#  ['actually',
#   'ordered',
#   'these',
#   'for',
#   'my',
#   'wife',
#   'and',
#   'she',
#   'love',
#   'them',
#   'she',
#   'also',
#   'love',
#   'the',
#   'way',
#   'the',
#   'toe'],
#  ['they',
#   'are',
#   'really',
#   'beautiful',
#   'earring',
#   'and',
#   'the',
#   'quality',
#   'is',
#   'just',
#   'right',
#   'they',
#   'have',
#   'nice'],
#  ['little',
#   'big',
#   'for',
#   'woman',
#   'the',
#   'wide',
#   'knee',
#   'part',
#   'is',
#   'little',
#   'small',
#   'for',
#   'man'],
#  ['very',
#   'comfortable',
#   'have',
#   'wide',
#   'foot',
#   'and',
#   'the',
#   'shoe',
#   'fit',
#   'perfectly',
#   'the',
#   'heel',
#   'is',
#   'just'],
#  ['didn',
#   'care',
#   'for',
#   'the',
#   'material',
#   'the',
#   'quality',
#   'is',
#   'just',
#   'what',
#   'wanted',
#   'just',
#   'the',
#   'way',
#   'it'],
#  ['good',
#   'size',
#   'for',
#   'event',
#   'where',
#   'have',
#   'the',
#   'time',
#   'and',
#   'money',
#   'nice',
#   'quality',
#   'very',
#   'pretty'],
#  ['love',
#   'this',
#   'shoe',
#   'it',
#   'comfortable',
#   'and',
#   'ha',
#   'the',
#   'wide',
#   'toe',
#   'box',
#   'the',
#   'only',
#   'reason',
#   'ordered'],
#  ['very',
#   'comfy',
#   'and',
#   'warm',
#   'it',
#   'look',
#   'great',
#   'and',
#   'the',
#   'material',
#   'are',
#   'good',
#   'am',
#   'year'],
#  ['high',
#   'quality',
#   'and',
#   'beautiful',
#   'detail',
#   'perfect',
#   'for',
#   'the',
#   'summer',
#   'very',
#   'good',
#   'quality'],
#  ['these',
#   'are',
#   'warm',
#   'and',
#   'comfortable',
#   'wear',
#   'size',
#   'and',
#   'it',
#   'fit',
#   'my',
#   'little',
#   'guy',
#   'perfectly'],
#  ['amazing',
#   'cute',
#   'little',
#   'crazy',
#   'for',
#   'boy',
#   'but',
#   'very',
#   'comfortable',
#   'the',
#   'only',
#   'reason',
#   'ordered',
#   'this'],
#  ['super',
#   'cute',
#   'wish',
#   'that',
#   'it',
#   'had',
#   'more',
#   'wide',
#   'width',
#   'normally',
#   'wear',
#   'size',
#   'and',
#   'ordered'],
#  ['this',
#   'one',
#   'is',
#   'perfect',
#   'for',
#   'me',
#   'the',
#   'quality',
#   'is',
#   'just',
#   'right',
#   'the',
#   'only',
#   'reason',
#   'ordered',
#   'this'],
#  ['these',
#   'jean',
#   'fit',
#   'weird',
#   'not',
#   'stretchy',
#   'at',
#   'all',
#   'normally',
#   'wear',
#   'size',
#   'and',
#   'ordered'],
#  ['love',
#   'the',
#   'shoe',
#   'love',
#   'it',
#   'it',
#   'comfortable',
#   'and',
#   'look',
#   'nice'],
#  ['fit',
#   'weird',
#   'tight',
#   'on',
#   'thigh',
#   'not',
#   'sure',
#   'if',
#   'the',
#   'knee',
#   'part',
#   'is',
#   'lot',
#   'tighter',
#   'but'],
#  ['super',
#   'cute',
#   'fit',
#   'bit',
#   'small',
#   'the',
#   'wide',
#   'knee',
#   'part',
#   'is',
#   'little',
#   'too',
#   'wide',
#   'for',
#   'me',
#   'but'],
#  ['did',
#   'not',
#   'like',
#   'the',
#   'fit',
#   'it',
#   'wa',
#   'too',
#   'long',
#   'will',
#   'return',
#   'it'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'comfortable',
#   'shoe',
#   'have',
#   'ever',
#   'owned',
#   'will',
#   'be',
#   'purchasing',
#   'more',
#   'in',
#   'other',
#   'color'],
#  ['very',
#   'pendulum',
#   'had',
#   'to',
#   'wear',
#   'an',
#   'elastic',
#   'band',
#   'around',
#   'the',
#   'waist',
#   'for',
#   'little',
#   'extra'],
#  ['bought',
#   'this',
#   'for',
#   'my',
#   'daughter',
#   'and',
#   'she',
#   'love',
#   'it',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag'],
#  ['great',
#   'quality',
#   'fast',
#   'delivery',
#   'the',
#   'picture',
#   'show',
#   'the',
#   'chain',
#   'is',
#   'little',
#   'loose',
#   'but',
#   'it',
#   'ok'],
#  ['these',
#   'are',
#   'my',
#   'favorite',
#   'pant',
#   'they',
#   'are',
#   'very',
#   'comfy',
#   'and',
#   'look',
#   'great'],
#  ['very',
#   'nice',
#   'fit',
#   'and',
#   'don',
#   'bunch',
#   'at',
#   'all',
#   'will',
#   'buy',
#   'again'],
#  ['the',
#   'shoe',
#   'fit',
#   'really',
#   'well',
#   'and',
#   'look',
#   'great',
#   'silver',
#   'not',
#   'gold'],
#  ['received',
#   'ring',
#   'today',
#   'the',
#   'workmanship',
#   'is',
#   'great',
#   'good',
#   'looking',
#   'ring'],
#  ['just',
#   'wanted',
#   'wanted',
#   'expected',
#   'and',
#   'ordered',
#   'good',
#   'job',
#   'thank',
#   'you'],
#  ['somewhat',
#   'lose',
#   'despite',
#   'being',
#   'size',
#   'good',
#   'to',
#   'use',
#   'during',
#   'the',
#   'summer'],
#  ['cute',
#   'dress',
#   'but',
#   'very',
#   'small',
#   'in',
#   'the',
#   'chest',
#   'not',
#   'true',
#   'xl'],
#  ['great',
#   'sweater',
#   'own',
#   'now',
#   'fun',
#   'way',
#   'to',
#   'switch',
#   'up',
#   'outfit'],
#  ['great',
#   'product',
#   'at',
#   'great',
#   'price',
#   'just',
#   'ordered',
#   'the',
#   'wrong',
#   'size'],
#  ['this', 'wa', 'purchased', 'gift', 'for', 'my', 'dad'],
#  ['they',
#   'were',
#   'too',
#   'small',
#   'around',
#   'my',
#   'calf',
#   'disappointed',
#   'because',
#   'really',
#   'liked',
#   'them'],
#  ['love',
#   'this',
#   'scarf',
#   'it',
#   'is',
#   'my',
#   'most',
#   'favorite',
#   'item',
#   'in',
#   'my',
#   'closet'],
#  ['my',
#   'son',
#   'love',
#   'this',
#   'vest',
#   'fit',
#   'great',
#   'comfortable',
#   'not',
#   'too',
#   'bulky'],
#  ['nice',
#   'costume',
#   'for',
#   'the',
#   'price',
#   'will',
#   'be',
#   'funny',
#   'for',
#   'our',
#   'party'],
#  ['great',
#   'for',
#   'covering',
#   'my',
#   'fat',
#   'and',
#   'scar',
#   'while',
#   'still',
#   'wearing',
#   'bikini'],
#  ['the',
#   'shoe',
#   'are',
#   'great',
#   'they',
#   'run',
#   'little',
#   'half',
#   'size',
#   'large'],
#  ['wear',
#   'these',
#   'shoe',
#   'everywhere',
#   'they',
#   'fit',
#   'great',
#   'and',
#   'are',
#   'very',
#   'comfy'],
#  ['bought',
#   'some',
#   'about',
#   'year',
#   'ago',
#   'just',
#   'bought',
#   'my',
#   'nd',
#   'set'],
#  ['love',
#   'them',
#   'very',
#   'comfortable',
#   'with',
#   'roomy',
#   'pocket',
#   'no',
#   'ironing',
#   'necessary'],
#  ['very',
#   'soft',
#   'and',
#   'fit',
#   'true',
#   'to',
#   'size',
#   'color',
#   'hold',
#   'up',
#   'very',
#   'well'],
#  ['great',
#   'novelty',
#   'shirt',
#   'im',
#   'expecting',
#   'to',
#   'get',
#   'plenty',
#   'of',
#   'laugh',
#   'from',
#   'it'],
#  ['very',
#   'stylish',
#   'and',
#   'well',
#   'made',
#   'the',
#   'heel',
#   'is',
#   'nice',
#   'height',
#   'for',
#   'work'],
#  ['bought',
#   'this',
#   'for',
#   'my',
#   'wife',
#   'she',
#   'say',
#   'it',
#   'fit',
#   'somewhat',
#   'small'],
#  ['perfect',
#   'exactly',
#   'what',
#   'wa',
#   'looking',
#   'for',
#   'to',
#   'attach',
#   'to',
#   'wallet'],
#  ['they', 'are', 'too', 'small', 'too', 'bad', 'they', 'are', 'very', 'cute'],
#  ['really', 'big', 'size', 'elegant', 'strong', 'and', 'very', 'beautiful'],
#  ['so',
#   'cozy',
#   'and',
#   'perfect',
#   'size',
#   'love',
#   'it',
#   'me',
#   'and',
#   'my',
#   'daughter',
#   'twining'],
#  ['great',
#   'comfortable',
#   'sandal',
#   'for',
#   'all',
#   'day',
#   'wear',
#   'but',
#   'beware',
#   'they',
#   'are',
#   'narrow'],
#  ['these', 'are', 'the', 'most', 'stylish', 'dress', 'sock', 'own'],
#  ['cream',
#   'color',
#   'go',
#   'great',
#   'with',
#   'anything',
#   'but',
#   'dirt',
#   'is',
#   'very',
#   'visible'],
#  ['very',
#   'tight',
#   'around',
#   'the',
#   'ankle',
#   'which',
#   'is',
#   'problem',
#   've',
#   'never',
#   'had'],
#  ['great',
#   'for',
#   'the',
#   'kid',
#   'at',
#   'our',
#   'pig',
#   'roast',
#   'we',
#   'had',
#   'this',
#   'summer'],
#  ['fit',
#   'great',
#   'very',
#   'comfortable',
#   'would',
#   'be',
#   'buying',
#   'few',
#   'more',
#   'pair'],
#  ['just',
#   'what',
#   'wanted',
#   'function',
#   'perfectly',
#   'for',
#   'what',
#   'need',
#   'it',
#   'for'],
#  ['gorgeous',
#   'color',
#   'versatile',
#   'wearing',
#   'capability',
#   'strong',
#   'fabric',
#   'without',
#   'being',
#   'heavy'],
#  ['great',
#   'if',
#   'you',
#   'have',
#   'huge',
#   'belly',
#   'or',
#   'shaped',
#   'like',
#   'box'],
#  ['this',
#   'is',
#   'so',
#   'cute',
#   'it',
#   'perfect',
#   'for',
#   'my',
#   'daughter',
#   'first',
#   'birthday',
#   'party'],
#  ['amazing',
#   'blanket',
#   'especially',
#   'for',
#   'summer',
#   'must',
#   'if',
#   'your',
#   'having',
#   'baby'],
#  ['wa',
#   'expecting',
#   'more',
#   'from',
#   'it',
#   'but',
#   'it',
#   'wasn',
#   'all',
#   'of',
#   'that'],
#  ['can', 'wear', 'light', 'sock', 'with', 'them', 'wishing', 'got', 'the'],
#  ['my',
#   'child',
#   'love',
#   'it',
#   'more',
#   'of',
#   'an',
#   'every',
#   'day',
#   'dress',
#   'and',
#   'play'],
#  ['made',
#   'in',
#   'usa',
#   'wanted',
#   'to',
#   'like',
#   'them',
#   'but',
#   'they',
#   'run',
#   'small'],
#  ['love',
#   'the',
#   'color',
#   'selection',
#   'could',
#   'use',
#   'green',
#   'one',
#   'though'],
#  ['my',
#   'wife',
#   'love',
#   'it',
#   'that',
#   'is',
#   'all',
#   'that',
#   'need',
#   'to',
#   'be',
#   'said'],
#  ['inside',
#   'stitch',
#   'rubbing',
#   'top',
#   'of',
#   'my',
#   'foot',
#   'making',
#   'my',
#   'walk',
#   'very',
#   'uncomfortable'],
#  ['the', 'fabric', 'is', 'amazing', 'but', 'size', 'is', 'really'],
#  ['nice',
#   'am',
#   'yet',
#   'to',
#   'wear',
#   'it',
#   'all',
#   'but',
#   'so',
#   'far',
#   'so',
#   'good'],
#  ['shoe', 'run', 'bit', 'larger', 'than', 'size', 'ordered', 'good', 'price'],
#  ['love',
#   'the',
#   'frye',
#   'boot',
#   'it',
#   'is',
#   'more',
#   'than',
#   'what',
#   'expected'],
#  ['very',
#   'cute',
#   'nice',
#   'and',
#   'thick',
#   'material',
#   'fit',
#   'expected',
#   'and',
#   'great',
#   'color'],
#  ['pendant',
#   'is',
#   'decent',
#   'but',
#   'the',
#   'chain',
#   'broke',
#   'very',
#   'easily',
#   'on',
#   'day',
#   'one'],
#  ['love',
#   'these',
#   'with',
#   'my',
#   'sneaker',
#   'and',
#   'chuck',
#   'stay',
#   'in',
#   'place',
#   'all',
#   'day'],
#  ['exactly', 'what', 'wa', 'looking', 'for', 'very', 'comfortable'],
#  ['have', 'pair', 'pair', 'of', 'the', 'same', 'pair', 'will', 'keep', 'them'],
#  ['display',
#   'your',
#   'american',
#   'patriotism',
#   'in',
#   'this',
#   'wallet',
#   'well',
#   'the',
#   'other'],
#  ['lb', 'ordered', 'size', 'up', 'it', 'fit', 'perfectly'],
#  ['good',
#   'pair',
#   'of',
#   'sunglass',
#   'especially',
#   'for',
#   'the',
#   'price',
#   've',
#   'had',
#   'them',
#   'for',
#   'couple',
#   'of',
#   'year'],
#  ['soft',
#   'adorable',
#   'high',
#   'quality',
#   'button',
#   'and',
#   'the',
#   'wide',
#   'width',
#   'make',
#   'them',
#   'nice',
#   'fit',
#   'for',
#   'person'],
#  ['think',
#   'ordered',
#   'the',
#   'correct',
#   'size',
#   'the',
#   'instruction',
#   'said',
#   'it',
#   'would',
#   'fit',
#   'just',
#   'fine'],
#  ['fit',
#   'perfectly',
#   'wash',
#   'very',
#   'well',
#   'ha',
#   'wide',
#   'width',
#   'and',
#   'is',
#   'comfortable'],
#  ['fit',
#   'my',
#   'glass',
#   'just',
#   'fine',
#   'love',
#   'the',
#   'look',
#   'and',
#   'fit',
#   'of',
#   'these',
#   'shoe'],
#  ['my',
#   'sister',
#   'said',
#   'it',
#   'feel',
#   'better',
#   'than',
#   'the',
#   'picture',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag',
#   'very',
#   'pretty'],
#  ['awesome',
#   'bag',
#   'especially',
#   'like',
#   'that',
#   'it',
#   'ha',
#   'an',
#   'arch',
#   'support',
#   'the',
#   'bag',
#   'is',
#   'very',
#   'pretty'],
#  ['fit',
#   'perfectly',
#   'love',
#   'the',
#   'asics',
#   'webbing',
#   'and',
#   'the',
#   'long',
#   'leg'],
#  ['run',
#   'small',
#   'sits',
#   'below',
#   'or',
#   'under',
#   'my',
#   'foot',
#   'not',
#   'too',
#   'tight',
#   'or',
#   'too',
#   'loose'],
#  ['wish',
#   'the',
#   'size',
#   'were',
#   'smaller',
#   'wear',
#   'an',
#   'xl',
#   'in',
#   'all',
#   'my',
#   'work',
#   'shoe',
#   'and',
#   'this'],
#  ['these',
#   'are',
#   'great',
#   'to',
#   'throw',
#   'on',
#   'or',
#   'wear',
#   'with',
#   'pant',
#   'will',
#   'keep',
#   'them',
#   'for',
#   'the',
#   'summer',
#   'and',
#   'they'],
#  ['using',
#   'for',
#   'costume',
#   'and',
#   'it',
#   'look',
#   'great',
#   'with',
#   'pant',
#   'will',
#   'keep',
#   'this',
#   'for',
#   'the',
#   'next',
#   'couple',
#   'of'],
#  ['returned',
#   'them',
#   'stone',
#   'show',
#   'through',
#   'the',
#   'quality',
#   'is',
#   'good',
#   'but',
#   'it',
#   'not',
#   'very',
#   'strong',
#   'one'],
#  ['they',
#   'were',
#   'exactly',
#   'what',
#   'wanted',
#   'the',
#   'quality',
#   'is',
#   'just',
#   'right',
#   'am',
#   'year',
#   'old'],
#  ['always',
#   'know',
#   'when',
#   'we',
#   'order',
#   'size',
#   'up',
#   'we',
#   've',
#   'had',
#   'lot',
#   'of',
#   'success',
#   'with',
#   'them'],
#  ['it',
#   'wa',
#   'hit',
#   'at',
#   'the',
#   'mall',
#   'and',
#   'the',
#   'chain',
#   'is',
#   'still',
#   'in',
#   'business',
#   'this',
#   'dress',
#   'is',
#   'awesome'],
#  ['ordered',
#   'for',
#   'my',
#   'year',
#   'old',
#   'daughter',
#   'and',
#   'she',
#   'love',
#   'it',
#   'she',
#   'wear',
#   'it',
#   'everyday',
#   'and',
#   'ha'],
#  ['love',
#   'this',
#   'top',
#   'it',
#   'ha',
#   'the',
#   'quality',
#   'and',
#   'comfort',
#   'of',
#   'top',
#   'that',
#   'is',
#   'comfortable',
#   'fit'],
#  ['very',
#   'small',
#   'and',
#   'neck',
#   'line',
#   'look',
#   'weird',
#   'but',
#   'it',
#   'is',
#   'what',
#   'it',
#   'appears',
#   'to',
#   'be',
#   'very',
#   'pretty'],
#  ['everything',
#   'wa',
#   'fine',
#   'the',
#   'fit',
#   'wa',
#   'little',
#   'tight',
#   'but',
#   'will',
#   'keep',
#   'it'],
#  ['not',
#   'heavy',
#   'look',
#   'great',
#   'on',
#   'wear',
#   'in',
#   'shoe',
#   'and',
#   'ordered'],
#  ['fit',
#   'great',
#   'on',
#   'my',
#   'wide',
#   'foot',
#   'normally',
#   'wear',
#   'size',
#   'and',
#   'ordered'],
#  ['loved',
#   'these',
#   'however',
#   'had',
#   'to',
#   'return',
#   'them',
#   'because',
#   'they',
#   'were',
#   'too',
#   'small',
#   'these',
#   'were',
#   'too',
#   'large',
#   'and'],
#  ['the',
#   'shoe',
#   'held',
#   'up',
#   'it',
#   'look',
#   'great',
#   'and',
#   'the',
#   'material',
#   'are',
#   'good',
#   'also',
#   'like',
#   'the',
#   'way',
#   'the'],
#  ['comfortable',
#   'but',
#   'expected',
#   'little',
#   'more',
#   'support',
#   'overall',
#   'good',
#   'purchase'],
#  ['very',
#   'light',
#   'and',
#   'cushiony',
#   'shoe',
#   'wear',
#   'an',
#   'xl',
#   'in',
#   'all',
#   'my',
#   'shoe',
#   'and',
#   'have'],
#  ['only',
#   'wear',
#   'chuck',
#   'and',
#   'this',
#   'is',
#   'the',
#   'only',
#   'one',
#   've',
#   'tried',
#   'have',
#   'wide',
#   'foot'],
#  ['this',
#   'wa',
#   'gift',
#   'and',
#   'it',
#   'look',
#   'great',
#   'with',
#   'the',
#   'sweater',
#   'also',
#   'like',
#   'the',
#   'way',
#   'the',
#   'front'],
#  ['good',
#   'sock',
#   'nice',
#   'pricing',
#   'excellent',
#   'quality',
#   'not',
#   'too',
#   'thin',
#   'or',
#   'too',
#   'thin'],
#  ['keeping',
#   'it',
#   'even',
#   'though',
#   'little',
#   'bulky',
#   'the',
#   'chain',
#   'stay',
#   'organized',
#   'and',
#   'easy',
#   'to',
#   'walk',
#   'in'],
#  ['bought',
#   'these',
#   'sneaker',
#   'like',
#   'the',
#   'stretchy',
#   'design',
#   'and',
#   'they',
#   'fit',
#   'great'],
#  ['item',
#   'arrived',
#   'on',
#   'time',
#   'and',
#   'look',
#   'great',
#   'it',
#   'is',
#   'little',
#   'snug',
#   'for',
#   'my',
#   'small',
#   'baby',
#   'but'],
#  ['perfect',
#   'and',
#   'doesnt',
#   'ride',
#   'or',
#   'go',
#   'down',
#   'the',
#   'side',
#   'of',
#   'my',
#   'foot',
#   'have',
#   'wide',
#   'foot',
#   'and'],
#  ['the',
#   'fabric',
#   'is',
#   'light',
#   'weight',
#   'wear',
#   'an',
#   'xl',
#   'in',
#   'this',
#   'shirt',
#   'the',
#   'shirt',
#   'is',
#   'just'],
#  ['great',
#   'glass',
#   'fit',
#   'me',
#   'great',
#   'cute',
#   'and',
#   'very',
#   'comfortable',
#   'love',
#   'the',
#   'style',
#   'and',
#   'the'],
#  ['great',
#   'quality',
#   'cut',
#   'it',
#   'in',
#   'half',
#   'with',
#   'thin',
#   'layer',
#   'of',
#   'clingy',
#   'fabric'],
#  ['absolutely',
#   'adorable',
#   'can',
#   'wait',
#   'to',
#   'wear',
#   'them',
#   'with',
#   'my',
#   'other',
#   'tom'],
#  ['best',
#   'nursing',
#   'bra',
#   'ever',
#   'after',
#   'reading',
#   'review',
#   'ordered',
#   'size',
#   'up',
#   'this',
#   'bra',
#   'is',
#   'bit'],
#  ['these',
#   'packing',
#   'cube',
#   'are',
#   'great',
#   'they',
#   'have',
#   'the',
#   'wide',
#   'width',
#   'and',
#   'fit',
#   'perfectly',
#   'they',
#   'have',
#   'nice',
#   'feel'],
#  ['great',
#   'shoe',
#   'but',
#   'they',
#   'do',
#   'run',
#   'little',
#   'small',
#   'normally',
#   'wear',
#   'size',
#   'and',
#   'ordered'],
#  ['great',
#   'looking',
#   'watch',
#   'for',
#   'the',
#   'price',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'come',
#   'with',
#   'small',
#   'buckle',
#   'and',
#   'the'],
#  ['love',
#   'these',
#   'for',
#   'working',
#   'out',
#   'they',
#   'are',
#   'comfortable',
#   'and',
#   'comfortable',
#   'also',
#   'like',
#   'the',
#   'way',
#   'they'],
#  ['obviously',
#   'cheaply',
#   'made',
#   'but',
#   'worth',
#   'it',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large'],
#  ['great',
#   'quality',
#   'and',
#   'price',
#   'for',
#   'what',
#   'they',
#   'are',
#   've',
#   'had',
#   'lot',
#   'of',
#   'success',
#   'with',
#   'them'],
#  ['my',
#   'husband',
#   'favorite',
#   'jean',
#   'they',
#   'are',
#   'little',
#   'wide',
#   'and',
#   'comfortable',
#   'but',
#   'they',
#   'are',
#   'also',
#   'little',
#   'loose'],
#  ['another',
#   'great',
#   'keen',
#   'product',
#   'look',
#   'great',
#   'and',
#   'the',
#   'material',
#   'are',
#   'good',
#   'have',
#   'wide',
#   'foot',
#   'and'],
#  ['the',
#   'spike',
#   'are',
#   'good',
#   'but',
#   'not',
#   'strong',
#   'the',
#   'other',
#   'two',
#   'the',
#   'only',
#   'reason',
#   'ordered',
#   'the'],
#  ['very',
#   'pleased',
#   'with',
#   'quality',
#   'for',
#   'the',
#   'price',
#   'will',
#   'make',
#   'nice',
#   'stick',
#   'in',
#   'xmas',
#   'gift'],
#  ['couldn',
#   'figure',
#   'out',
#   'how',
#   'to',
#   'wear',
#   'this',
#   'thing',
#   'no',
#   'instruction',
#   'were',
#   'included'],
#  ['no',
#   'elastic',
#   'or',
#   'drawstring',
#   'in',
#   'waist',
#   'so',
#   'after',
#   'washing',
#   'they',
#   'don',
#   'fit',
#   'anymore'],
#  ['fit',
# ...
#   'up',
#   'so',
#   'far',
#   'in',
#   'the',
#   'wash'],
#  ['cute',
#   'little',
#   'purse',
#   'gave',
#   'it',
#   'to',
#   'my',
#   'sister',
#   'gift',
#   'perfect',
#   'with',
#   'jean',
#   'or',
#   'other',
#   'casual',
#   'outfit'],
#  ['my',
#   'year',
#   'old',
#   'got',
#   'ton',
#   'of',
#   'use',
#   'in',
#   'the',
#   'snow',
#   'and',
#   'mud',
#   'never',
#   'leaked',
#   'no',
#   'cold',
#   'foot'],
#  ['omg',
#   'these',
#   'are',
#   'so',
#   'comfy',
#   'and',
#   'they',
#   'pair',
#   'well',
#   'with',
#   'dress',
#   'or',
#   'jean',
#   'very',
#   'happy',
#   'with',
#   'this',
#   'purchase'],
#  ['im',
#   'usually',
#   'size',
#   'and',
#   'it',
#   'fit',
#   'however',
#   'would',
#   'be',
#   'perfect',
#   'love',
#   'the',
#   'style',
#   'and',
#   'look'],
#  ['these',
#   'are',
#   'the',
#   'most',
#   'awesome',
#   'shoe',
#   'am',
#   'going',
#   'to',
#   'order',
#   'more',
#   'color',
#   'soon',
#   'can'],
#  ['it',
#   'christmas',
#   'gift',
#   'so',
#   'not',
#   'really',
#   'sure',
#   'how',
#   'it',
#   'will',
#   'fit',
#   'but',
#   'it',
#   'look',
#   'like',
#   'the',
#   'right',
#   'size'],
#  ['normally', 'wear', 'size', 'to', 'with', 'this', 'shoe', 'wear', 'size'],
#  ['love',
#   'these',
#   'very',
#   'comfortable',
#   'perfect',
#   'for',
#   'between',
#   'season',
#   'when',
#   'you',
#   're',
#   'done',
#   'with',
#   'boot',
#   'but',
#   'not',
#   'quite',
#   'ready',
#   'for',
#   'sandles'],
#  ['this',
#   'is',
#   'really',
#   'little',
#   'shirt',
#   'certainly',
#   'not',
#   'dress',
#   'and',
#   'the',
#   'small',
#   'wa',
#   'too',
#   'small'],
#  ['ordered',
#   'half',
#   'size',
#   'larger',
#   'due',
#   'to',
#   'recommendation',
#   'couldn',
#   'be',
#   'happier',
#   'fit',
#   'great',
#   'and',
#   'no',
#   'sign',
#   'of',
#   'premature',
#   'wear',
#   'yet'],
#  ['cute',
#   'style',
#   'but',
#   'not',
#   'the',
#   'best',
#   'quality',
#   'gemstone',
#   'fall',
#   'off',
#   'easily',
#   'and',
#   'zipper',
#   'on',
#   'back',
#   'of',
#   'sandal',
#   'get',
#   'stuck'],
#  ['after',
#   'the',
#   'exchange',
#   'satisfied',
#   'the',
#   'last',
#   'pair',
#   'looked',
#   'counterfeit',
#   'the',
#   'logo',
#   'wa',
#   'off',
#   'center',
#   'but',
#   'they',
#   'look',
#   'great',
#   'now'],
#  ['sturdy',
#   'shoe',
#   'autistic',
#   'daughter',
#   'wore',
#   'them',
#   'everyday',
#   'during',
#   'the',
#   'cold',
#   'month',
#   'she',
#   'hate',
#   'shoe',
#   'but',
#   'tolerated',
#   'these'],
#  ['bought',
#   'this',
#   'for',
#   'my',
#   'daughter',
#   'whose',
#   'name',
#   'is',
#   'amber',
#   'christmas',
#   'ago',
#   'she',
#   'still',
#   'wear',
#   'it',
#   'every',
#   'day'],
#  ['the',
#   'green',
#   'in',
#   'these',
#   'is',
#   'so',
#   'pretty',
#   'very',
#   'eye',
#   'catching',
#   'the',
#   'lever',
#   'back',
#   'is',
#   'my',
#   'favorite',
#   'gorgeous'],
#  ['sadly',
#   'not',
#   'sewn',
#   'well',
#   'one',
#   'pair',
#   'fell',
#   'apart',
#   'put',
#   'them',
#   'on',
#   'size',
#   'wa',
#   'fine',
#   'just',
#   'poor',
#   'construction'],
#  ['not',
#   'sticky',
#   'other',
#   'brand',
#   'but',
#   'otherwise',
#   'are',
#   'perfect',
#   'nice',
#   'to',
#   'wear',
#   'under',
#   'particularly',
#   'thin',
#   'bralette'],
#  ['always',
#   'love',
#   'always',
#   'fit',
#   'great',
#   'just',
#   'like',
#   'the',
#   'original',
#   'and',
#   'they',
#   'last',
#   'for',
#   'year',
#   'won',
#   'buy',
#   'any',
#   'others'],
#  ['good',
#   'quality',
#   'fit',
#   'good',
#   'have',
#   'bought',
#   'several',
#   'color',
#   'in',
#   'long',
#   'sleeve',
#   'and',
#   'short',
#   'looking',
#   'for',
#   'short',
#   'sleeve',
#   'white'],
#  ['very',
#   'flat',
#   'but',
#   'cute',
#   'and',
#   'work',
#   'for',
#   'narrow',
#   'ish',
#   'foot',
#   'the',
#   'strap',
#   'fit',
#   'well',
#   'against',
#   'the',
#   'foot',
#   'without',
#   'gap'],
#  ['started',
#   'using',
#   'these',
#   'at',
#   'month',
#   'with',
#   'my',
#   'girl',
#   'who',
#   'is',
#   'petite',
#   'and',
#   'still',
#   'using',
#   'them',
#   'good',
#   'purchase'],
#  ['above',
#   'average',
#   'heavy',
#   'denim',
#   'jean',
#   'which',
#   'is',
#   'all',
#   'wear',
#   'at',
#   'great',
#   'price',
#   'to',
#   'me',
#   'carhartt',
#   'is',
#   'special'],
#  ['nice',
#   'cape',
#   'it',
#   'really',
#   'made',
#   'my',
#   'costume',
#   'complete',
#   'dark',
#   'green',
#   'velvet',
#   'with',
#   'tie',
#   'at',
#   'neck',
#   'one',
#   'suze',
#   'fit',
#   'all'],
#  ['love',
#   'the',
#   'light',
#   'feature',
#   'easy',
#   'on',
#   'and',
#   'off',
#   'and',
#   'easy',
#   'to',
#   'read',
#   'what',
#   'more',
#   'can',
#   'you',
#   'ask',
#   'for'],
#  ['best',
#   'bra',
#   'ever',
#   'follow',
#   'the',
#   'fitting',
#   'guide',
#   'and',
#   'you',
#   'can',
#   'go',
#   'wrong',
#   'they',
#   'fit',
#   'great',
#   'are',
#   'comfortable',
#   'and',
#   'last'],
#  ['love',
#   'love',
#   'this',
#   'belt',
#   'instantly',
#   'my',
#   'favorite',
#   'one',
#   'perfect',
#   'fit',
#   'cut',
#   'to',
#   'size',
#   'and',
#   'adjustable',
#   'every',
#   'pair',
#   'of',
#   'pant'],
#  ['this',
#   'is',
#   'just',
#   'perfect',
#   'the',
#   'color',
#   'work',
#   'just',
#   'great',
#   'and',
#   'it',
#   'match',
#   'with',
#   'the',
#   'color',
#   'for',
#   'the',
#   'wedding'],
#  ['these',
#   'lilac',
#   'bloom',
#   'legging',
#   'are',
#   'pretty',
#   'color',
#   'very',
#   'soft',
#   'and',
#   'comfortable',
#   'will',
#   'be',
#   'getting',
#   'more',
#   'in',
#   'different',
#   'color'],
#  ['very',
#   'pretty',
#   'and',
#   'great',
#   'quality',
#   'fabric',
#   'and',
#   'machine',
#   'washable',
#   'it',
#   'wa',
#   'given',
#   'gift',
#   'and',
#   'they',
#   'loved',
#   'it'],
#  ['it',
#   'product',
#   'worth',
#   'what',
#   'it',
#   'cost',
#   'and',
#   'the',
#   'quality',
#   'is',
#   'great'],
#  ['wa',
#   'pleasantly',
#   'surprised',
#   'with',
#   'this',
#   'dress',
#   'the',
#   'material',
#   'is',
#   'thick',
#   'and',
#   'it',
#   'is',
#   'very',
#   'comfortable'],
#  ['doe',
#   'make',
#   'whining',
#   'sound',
#   'but',
#   'thought',
#   'it',
#   'wa',
#   'little',
#   'too',
#   'loud',
#   'for',
#   'the',
#   'person',
#   'who',
#   'is'],
#  ['but',
#   'also',
#   'smaller',
#   'than',
#   'appeared',
#   'on',
#   'the',
#   'picture',
#   'not',
#   'sure',
#   'if',
#   'it',
#   'just',
#   'the',
#   'sizing',
#   'or',
#   'if'],
#  ['need',
#   'some',
#   'time',
#   'to',
#   'break',
#   'them',
#   'in',
#   'they',
#   'look',
#   'great',
#   'the',
#   'only',
#   'reason',
#   'ordered',
#   'the'],
#  ['hi',
#   'that',
#   'wa',
#   'my',
#   'size',
#   'and',
#   'it',
#   'fit',
#   'fine',
#   'very',
#   'good',
#   'quality'],
#  ['mine',
#   'doe',
#   'not',
#   'have',
#   'the',
#   'material',
#   'of',
#   'the',
#   'wide',
#   'width',
#   'will',
#   'return',
#   'it'],
#  ['these',
#   'bib',
#   'are',
#   'excellent',
#   'they',
#   'are',
#   'stretchy',
#   'and',
#   'very',
#   'comfortable',
#   'also',
#   'like',
#   'the'],
#  ['no',
#   'complaint',
#   'other',
#   'than',
#   'professional',
#   'with',
#   'comfortable',
#   'fit',
#   'these',
#   'pant',
#   'are',
#   'great'],
#  ['this',
#   'is',
#   'my',
#   'nd',
#   'pair',
#   'of',
#   'these',
#   'and',
#   'they',
#   'are',
#   'comfortable',
#   'also',
#   'like',
#   'the',
#   'way',
#   'the'],
#  ['just',
#   'little',
#   'upset',
#   'had',
#   'to',
#   'return',
#   'it',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag',
#   'very',
#   'pretty'],
#  ['comfortable',
#   'and',
#   'daughter',
#   'used',
#   'it',
#   'for',
#   'trip',
#   'to',
#   'the',
#   'beach',
#   'the',
#   'only',
#   'reason',
#   'gave'],
#  ['nice',
#   'looking',
#   'shoe',
#   'comfortable',
#   'but',
#   'not',
#   'bulky',
#   'it',
#   'is',
#   'little',
#   'snug',
#   'for',
#   'my',
#   'foot',
#   'but'],
#  ['have',
#   'pair',
#   'of',
#   'gloria',
#   'vanderbilt',
#   'lost',
#   'weight',
#   'and',
#   'broke',
#   'in'],
#  ['my',
#   'son',
#   'is',
#   'racing',
#   'all',
#   'the',
#   'time',
#   'and',
#   'the',
#   'chain',
#   'is',
#   'too',
#   'tight',
#   'around',
#   'his',
#   'waist'],
#  ['fabric',
#   'with',
#   'wood',
#   'like',
#   'piece',
#   'love',
#   'the',
#   'look',
#   'and',
#   'feel',
#   'of',
#   'these',
#   'shoe'],
#  ['my',
#   'wife',
#   'loved',
#   'these',
#   'so',
#   'much',
#   'she',
#   'kept',
#   'them',
#   'very',
#   'good',
#   'quality',
#   'nice',
#   'bag',
#   'very',
#   'pretty'],
#  ['great',
#   'sock',
#   'don',
#   'have',
#   'to',
#   'break',
#   'them',
#   'in',
#   'will',
#   'keep',
#   'them',
#   'for',
#   'the',
#   'next'],
#  ['pretty',
#   'sporty',
#   'and',
#   'fit',
#   'perfect',
#   'wear',
#   'size',
#   'and',
#   'it',
#   'fit',
#   'my',
#   'little',
#   'guy',
#   'perfectly'],
#  ['this',
#   'bra',
#   'is',
#   'very',
#   'comfortable',
#   'and',
#   'ha',
#   'the',
#   'wide',
#   'width',
#   'normally',
#   'wear',
#   'size',
#   'and',
#   'ordered'],
#  ['love',
#   'how',
#   'sleek',
#   'and',
#   'stylish',
#   'it',
#   'is',
#   'it',
#   'is',
#   'little',
#   'snug',
#   'around',
#   'my',
#   'hip',
#   'but',
#   'not',
#   'too'],
#  ['this',
#   'is',
#   'the',
#   'perfect',
#   'vid',
#   'for',
#   'the',
#   'wide',
#   'width',
#   'will',
#   'keep',
#   'this',
#   'for',
#   'the',
#   'next',
#   'couple',
#   'of'],
#  ['have',
#   'used',
#   'this',
#   'brand',
#   'for',
#   'couple',
#   'year',
#   'now',
#   'and',
#   'will',
#   'keep',
#   'my',
#   'foot',
#   'in',
#   'this',
#   'brand'],
#  ['very',
#   'dissatisfied',
#   'after',
#   'wearing',
#   'this',
#   'pair',
#   'of',
#   'shoe',
#   'for',
#   'week',
#   'have',
#   'hard',
#   'time',
#   'finding',
#   'shoe'],
#  ['cute',
#   'but',
#   'wide',
#   'at',
#   'the',
#   'waist',
#   'the',
#   'wide',
#   'width',
#   'is',
#   'good',
#   'enough'],
#  ['my',
#   'husband',
#   'say',
#   'these',
#   'are',
#   'perfect',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'they',
#   'are',
#   'kind',
#   'of',
#   'small'],
#  ['awesome',
#   'passport',
#   'holder',
#   'love',
#   'the',
#   'look',
#   'of',
#   'the',
#   'design',
#   'and',
#   'the',
#   'fit',
#   'the',
#   'bag',
#   'is',
#   'very'],
#  ['bought',
#   'this',
#   'for',
#   'halloween',
#   'costume',
#   'and',
#   'it',
#   'wa',
#   'just',
#   'what',
#   'wanted',
#   'it',
#   'pretty',
#   'dress'],
#  ['recommend',
#   'this',
#   'product',
#   'it',
#   'is',
#   'an',
#   'amazing',
#   'quality',
#   'and',
#   'comfortable',
#   'fit',
#   'have',
#   'wide',
#   'foot'],
#  ['the',
#   'quality',
#   'of',
#   'the',
#   'material',
#   'is',
#   'excellent',
#   'and',
#   'the',
#   'material',
#   'are',
#   'thick',
#   'enough',
#   'to',
#   'make',
#   'wearing',
#   'shirt',
#   'uncomfortable'],
#  ['used',
#   'the',
#   'size',
#   'chart',
#   'and',
#   'it',
#   'wa',
#   'fine',
#   'will',
#   'keep',
#   'this',
#   'bag',
#   'in',
#   'my',
#   'collection'],
#  ['love',
#   'the',
#   'material',
#   'and',
#   'the',
#   'material',
#   'is',
#   'nice',
#   'the',
#   'fit',
#   'is',
#   'nice',
#   'the',
#   'heel',
#   'is',
#   'just'],
#  ['bought',
#   'they',
#   'were',
#   'perfect',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'they',
#   'are',
#   'very',
#   'thin'],
#  ['these',
#   'ripped',
#   'the',
#   'first',
#   'time',
#   'wore',
#   'them',
#   'wa',
#   'little',
#   'surprised',
#   'that',
#   'the',
#   'buckle',
#   'broke'],
#  ['purchased',
#   'these',
#   'boot',
#   'for',
#   'my',
#   'wife',
#   'and',
#   'she',
#   'love',
#   'them',
#   'she',
#   'also',
#   'love',
#   'the',
#   'way',
#   'the',
#   'toe'],
#  ['really',
#   'nice',
#   'quality',
#   'and',
#   'an',
#   'excellent',
#   'price',
#   'just',
#   'wish',
#   'it',
#   'wa',
#   'more',
#   'of',
#   'size',
#   'larger'],
#  ['authentic',
#   'chuck',
#   'taylor',
#   'shoe',
#   'they',
#   'have',
#   'the',
#   'wide',
#   'width',
#   'and',
#   'fit',
#   'perfectly'],
#  ['it',
#   'is',
#   'lavender',
#   'stated',
#   'it',
#   'is',
#   'very',
#   'comfortable',
#   'fit',
#   'the',
#   'only',
#   'reason',
#   'ordered'],
#  ['my',
#   'new',
#   'favorite',
#   'go',
#   'to',
#   'pair',
#   'of',
#   'shoe',
#   've',
#   'always',
#   'wanted',
#   'to',
#   'have',
#   'pair',
#   'of',
#   'these'],
#  ['these',
#   'are',
#   'great',
#   'shower',
#   'shoe',
#   'but',
#   'the',
#   'wide',
#   'width',
#   'make',
#   'them',
#   'uncomfortable',
#   'these',
#   'have',
#   'wide',
#   'heel'],
#  ['perfect',
#   'summer',
#   'shoe',
#   'go',
#   'with',
#   'everything',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'it',
#   'little',
#   'too',
#   'large'],
#  ['love',
#   'this',
#   'earring',
#   'simple',
#   'classy',
#   'and',
#   'very',
#   'comfortable',
#   'the',
#   'only',
#   'reason'],
#  ['so',
#   'happy',
#   'didn',
#   'have',
#   'to',
#   'wear',
#   'the',
#   'knee',
#   'pad',
#   'also',
#   'have',
#   'wide'],
#  ['great', 'shoe', 'fit', 'real', 'gooooooood', 'wear', 'in', 'these', 'shoe'],
#  ['love',
#   'them',
#   'there',
#   'size',
#   'is',
#   'perfect',
#   'the',
#   'only',
#   'problem',
#   'is',
#   'that',
#   'they',
#   'are',
#   'very',
#   'thin'],
#  ['fit',
#   'like',
#   'wouldn',
#   'expect',
#   'it',
#   'very',
#   'comfortable',
#   'shoe',
#   'have',
#   'wide'],
#  ['my',
#   'daughter',
#   'love',
#   'these',
#   'shoe',
#   'they',
#   'are',
#   'comfortable',
#   'and',
#   'look',
#   'great',
#   'my',
#   'daughter',
#   'also',
#   'love',
#   'the',
#   'way',
#   'the'],
#  ['fit',
#   'smaller',
#   'than',
#   'most',
#   'used',
#   'this',
#   'to',
#   'wear',
#   'with',
#   'sweater',
#   'also',
#   'have',
#   'large',
#   'bust'],
#  ['my',
#   'only',
#   'complaint',
#   'is',
#   'that',
#   'the',
#   'strap',
#   'were',
#   'bit',
#   'long',
#   'but',
#   'very',
#   'good',
#   'quality',
#   'will',
#   'buy',
#   'this',
#   'brand',
#   'again'],
#  ['wa',
#   'thinking',
#   'they',
#   'were',
#   'more',
#   'compression',
#   'than',
#   'they',
#   'are',
#   'they',
#   'are',
#   'nice',
#   'and',
#   'soft',
#   'but',
#   'they',
#   'provide',
#   'no',
#   'compression'],
#  ['little',
#   'small',
#   'but',
#   'maybe',
#   'due',
#   'to',
#   'curvy',
#   'gal',
#   'def',
#   'show',
#   'em',
#   'all',
#   'beautiful',
#   'dress',
#   'all',
#   'the',
#   'same'],
#  ['this',
#   'will',
#   'replace',
#   'my',
#   'garment',
#   'bag',
#   'that',
#   'took',
#   'on',
#   'many',
#   'trip',
#   'so',
#   'glad',
#   'that',
#   'it',
#   'ha',
#   'wheel'],
#  ['got',
#   'these',
#   'for',
#   'cruise',
#   'joke',
#   'during',
#   'the',
#   'formal',
#   'meal',
#   'worked',
#   'advertised',
#   'but',
#   'they',
#   'are',
#   'made',
#   'for',
#   'kid'],
#  ['nice',
#   'looking',
#   'slipper',
#   'not',
#   'that',
#   'comfortable',
#   'and',
#   'started',
#   'falling',
#   'apart',
#   'ended',
#   'up',
#   'buying',
#   'cheap',
#   'slipper',
#   'from',
#   'the',
#   'neighborhood',
#   'mart'],
#  ['they',
#   'fit',
#   'perfect',
#   'they',
#   'look',
#   'expensive',
#   'they',
#   'are',
#   'the',
#   'most',
#   'confortable',
#   'shoe',
#   'that',
#   'had',
#   'ever',
#   'love',
#   'the',
#   'design'],
#  ['this',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'first',
#   'one',
#   'ordered',
#   'it',
#   'really',
#   'nice',
#   'blzaer',
#   'would',
#   'totally',
#   'recommend',
#   'it'],
#  ['have',
#   'bought',
#   'at',
#   'least',
#   'ten',
#   'pair',
#   'and',
#   'these',
#   'are',
#   'just',
#   'wrong',
#   'strongly',
#   'do',
#   'not',
#   'recommend',
#   'this',
#   'product',
#   'sadly'],
#  ['work',
#   'well',
#   'so',
#   'far',
#   'and',
#   'is',
#   'quite',
#   'pretty',
#   'nice',
#   'subtle',
#   'deep',
#   'burgundy',
#   'purple',
#   'band',
#   'very',
#   'easy',
#   'to',
#   'read',
#   'face',
#   'elegant'],
#  ['could',
#   'get',
#   'this',
#   'top',
#   'on',
#   'but',
#   'the',
#   'fabric',
#   'wa',
#   'stretched',
#   'so',
#   'much',
#   'that',
#   'you',
#   'could',
#   'see',
#   'right',
#   'through',
#   'it'],
#  ['gift',
#   'for',
#   'belated',
#   'baptism',
#   'year',
#   'old',
#   'this',
#   'is',
#   'perfect',
#   'size',
#   'for',
#   'her',
#   'and',
#   'know',
#   'she',
#   'll',
#   'enjoy',
#   'it'],
#  ['fit',
#   'good',
#   'feel',
#   'good',
#   'so',
#   'comfortable',
#   'forget',
#   'have',
#   'them',
#   'on',
#   'have',
#   'no',
#   'complaint',
#   'at',
#   'this',
#   'time'],
#  ['needed',
#   'an',
#   'inexpensive',
#   'belt',
#   'for',
#   'outdoor',
#   'chore',
#   'this',
#   'is',
#   'exactly',
#   'what',
#   'wa',
#   'looking',
#   'for',
#   'in',
#   'both',
#   'price',
#   'and',
#   'quality'],
#  ['arrived',
#   'on',
#   'time',
#   'guess',
#   'have',
#   'small',
#   'wrist',
#   'little',
#   'big',
#   'but',
#   'will',
#   'wear',
#   'it',
#   'daily',
#   'with',
#   'beaded',
#   'bracelet'],
#  ['bought',
#   'this',
#   'to',
#   'take',
#   'with',
#   'me',
#   'to',
#   'paris',
#   'london',
#   'my',
#   'jewelry',
#   'fit',
#   'nice',
#   'in',
#   'there',
#   'it',
#   'nicely',
#   'made',
#   'too',
#   'classy'],
#  ['how',
#   'could',
#   'you',
#   'not',
#   'like',
#   'the',
#   'price',
#   'and',
#   'it',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'good',
#   'looking',
#   'ring',
#   'besides'],
#  ['bought',
#   'this',
#   'gift',
#   'she',
#   'will',
#   'surely',
#   'know',
#   'it',
#   'gag',
#   'gift',
#   'it',
#   'look',
#   'incredibly',
#   'cheap'],
#  ['now',
#   'wear',
#   'fit',
#   'flop',
#   'sneaker',
#   'sandal',
#   'and',
#   'slipper',
#   'and',
#   'my',
#   'foot',
#   'are',
#   'happy',
#   'maybe',
#   'boot',
#   'will',
#   'be',
#   'next'],
#  ['great',
#   'slipper',
#   'run',
#   'to',
#   'maybe',
#   'full',
#   'size',
#   'too',
#   'long',
#   'not',
#   'to',
#   'wide',
#   'too',
#   'long',
#   'great',
#   'leather',
#   'soft',
#   'comfortable'],
#  ...]

# %%
import gensim
import numpy as n

# %%
model = gensim.models.Word2Vec(words)
model.wv.index_to_key
# Out:
# ['the',
#  'and',
#  'it',
#  'is',
#  'to',
#  'for',
#  'this',
#  'my',
#  'of',
#  'very',
#  'they',
#  'are',
#  'but',
#  'fit',
#  'in',
#  'these',
#  'have',
#  'size',
#  'them',
#  'that',
#  'not',
#  'with',
#  'comfortable',
#  'love',
#  'wear',
#  'wa',
#  'shoe',
#  'on',
#  'great',
#  'so',
#  'little',
#  'will',
#  'be',
#  'like',
#  'too',
#  'nice',
#  'you',
#  'he',
#  'would',
#  'ordered',
#  'am',
#  'look',
#  'good',
#  'just',
#  'bought',
#  'color',
#  'perfect',
#  'material',
#  'had',
#  'foot',
#  'quality',
#  'well',
#  'small',
#  'me',
#  'one',
#  'if',
#  'pair',
#  'only',
#  'up',
#  'than',
#  'wide',
#  'all',
#  'bit',
#  'can',
#  'or',
#  'large',
#  'more',
#  'time',
#  'dress',
#  'soft',
#  'perfectly',
#  'because',
#  'get',
#  'at',
#  'she',
#  'long',
#  'shirt',
#  'really',
#  'also',
#  'ha',
#  'tight',
#  'other',
#  'an',
#  'out',
#  'wearing',
#  'boot',
#  'recommend',
#  'made',
#  'bag',
#  'day',
#  'were',
#  'year',
#  'pretty',
#  'when',
#  'happy',
#  'from',
#  'don',
#  'keep',
#  'son',
#  'price',
#  'cute',
#  'no',
#  'about',
#  've',
#  'got',
#  'which',
#  'big',
#  'what',
#  'feel',
#  'do',
#  'still',
#  'buy',
#  'work',
#  'medium',
#  'expected',
#  'watch',
#  'top',
#  'way',
#  'bra',
#  'around',
#  'much',
#  'thin',
#  'purchase',
#  'looking',
#  'right',
#  'back',
#  'go',
#  'been',
#  'say',
#  'fabric',
#  'problem',
#  'order',
#  'your',
#  'some',
#  're',
#  'make',
#  'lot',
#  'enough',
#  'definitely',
#  'short',
#  'front',
#  'review',
#  'even',
#  'product',
#  'him',
#  'daughter',
#  'strap',
#  'jean',
#  'husband',
#  'there',
#  'now',
#  'worn',
#  'off',
#  'think',
#  'after',
#  'reason',
#  'did',
#  'another',
#  'thing',
#  'style',
#  'few',
#  'beautiful',
#  'pleased',
#  'pant',
#  'heel',
#  'use',
#  'first',
#  'down',
#  'could',
#  'sure',
#  'sock',
#  'who',
#  'support',
#  'fine',
#  'need',
#  'smaller',
#  'waist',
#  'going',
#  'how',
#  'lb',
#  'same',
#  'any',
#  'we',
#  'stretchy',
#  'light',
#  'different',
#  'doe',
#  'warm',
#  'normally',
#  'width',
#  'most',
#  'toe',
#  'his',
#  'find',
#  'xl',
#  'wish',
#  'couple',
#  'narrow',
#  'again',
#  'ring',
#  'wanted',
#  'hold',
#  'larger',
#  'part',
#  'star',
#  'return',
#  'll',
#  'run',
#  'didn',
#  'put',
#  'received',
#  'loose',
#  'her',
#  'two',
#  'loved',
#  'length',
#  'easy',
#  'hard',
#  'wallet',
#  'usually',
#  'month',
#  'over',
#  'area',
#  'thought',
#  'pocket',
#  'by',
#  'better',
#  'come',
#  'purchased',
#  'though',
#  'since',
#  'leather',
#  'picture',
#  'snug',
#  'want',
#  'buying',
#  'black',
#  'last',
#  'brand',
#  'best',
#  'super',
#  'give',
#  'high',
#  'anyone',
#  'second',
#  'however',
#  'old',
#  'bottom',
#  'doesn',
#  'item',
#  'used',
#  'box',
#  'band',
#  'thick',
#  'gift',
#  'see',
#  'zipper',
#  'every',
#  'weight',
#  'issue',
#  'half',
#  'know',
#  'sizing',
#  'summer',
#  'side',
#  'comfy',
#  'sandal',
#  'arch',
#  'inside',
#  'said',
#  'many',
#  'highly',
#  'wore',
#  'into',
#  'while',
#  'probably',
#  'tried',
#  'before',
#  'true',
#  'hour',
#  'fan',
#  'then',
#  'exactly',
#  'chest',
#  'never',
#  'without',
#  'something',
#  'should',
#  'ever',
#  'slightly',
#  'hat',
#  'always',
#  'amazon',
#  'being',
#  'wash',
#  'bigger',
#  'might',
#  'life',
#  'longer',
#  'extra',
#  'cheap',
#  'chain',
#  'overall',
#  'take',
#  'design',
#  'needed',
#  'seems',
#  'huge',
#  'new',
#  'white',
#  'walking',
#  'birthday',
#  'found',
#  'wife',
#  'money',
#  'leg',
#  'jacket',
#  'room',
#  'try',
#  'disappointed',
#  'comfort',
#  'far',
#  'quite',
#  'sleeve',
#  'stretch',
#  'set',
#  'sole',
#  'several',
#  'under',
#  'may',
#  'both',
#  'woman',
#  'through',
#  'value',
#  'head',
#  'gave',
#  'yet',
#  'tighter',
#  'where',
#  'getting',
#  'compliment',
#  'able',
#  'week',
#  'next',
#  'ankle',
#  'actually',
#  'came',
#  'easily',
#  'knee',
#  'worth',
#  'heavy',
#  'kind',
#  'stiff',
#  'blue',
#  'belt',
#  'excellent',
#  'often',
#  'shoulder',
#  'arrived',
#  'favorite',
#  'walk',
#  'costume',
#  'show',
#  'buckle',
#  'north',
#  'own',
#  'sneaker',
#  'read',
#  'liked',
#  'flattering',
#  'adjustable',
#  'lightweight',
#  'anything',
#  'everyday',
#  'once',
#  'house',
#  'ok',
#  'almost',
#  'tall',
#  'person',
#  'sturdy',
#  'solid',
#  'piece',
#  'bad',
#  'cup',
#  'amazing',
#  'hand',
#  'durable',
#  'trip',
#  'uncomfortable',
#  'fact',
#  'inch',
#  'dakota',
#  'complaint',
#  'bright',
#  'seem',
#  'vibrant',
#  'end',
#  'extremely',
#  'fall',
#  'stay',
#  'ordering',
#  'glad',
#  'absolutely',
#  'itself',
#  'others',
#  'deal',
#  'elastic',
#  'place',
#  'their',
#  'type',
#  'case',
#  'especially',
#  'hoping',
#  'cotton',
#  'necklace',
#  'everything',
#  'regular',
#  'looked',
#  'having',
#  'dry',
#  'shape',
#  'bulky',
#  'body',
#  'help',
#  'awesome',
#  'lace',
#  'finding',
#  'why',
#  'full',
#  'took',
#  'normal',
#  'arm',
#  'real',
#  'bust',
#  'those',
#  'won',
#  'purchasing',
#  'cut',
#  'outside',
#  'slip',
#  'gold',
#  'store',
#  'low',
#  'update',
#  'maybe',
#  'here',
#  'christmas',
#  'nicely',
#  'already',
#  'carry',
#  'bracelet',
#  'change',
#  'expect',
#  'okay',
#  'returned',
#  'photo',
#  'honest',
#  'three',
#  'break',
#  'went',
#  'running',
#  'water',
#  'baby',
#  'plus',
#  'skirt',
#  'earring',
#  'returning',
#  'jewelry',
#  'casual',
#  'either',
#  'shipping',
#  'purse',
#  'silver',
#  'friend',
#  'weather',
#  'wedding',
#  'strong',
#  'surprised',
#  'winter',
#  'red',
#  'replace',
#  'suit',
#  'plastic',
#  'seam',
#  'hope',
#  'haven',
#  'nothing',
#  'guess',
#  'using',
#  'isn',
#  'people',
#  'quickly',
#  'dark',
#  'felt',
#  'bed',
#  'gotten',
#  'brown',
#  'card',
#  'cover',
#  'less',
#  'button',
#  'daily',
#  'wrong',
#  'glove',
#  'stylish',
#  'kept',
#  'myself',
#  'slipper',
#  'someone',
#  'job',
#  'wardrobe',
#  'lovely',
#  'girl',
#  'calf',
#  'pound',
#  'otherwise',
#  'open',
#  'men',
#  'line',
#  'cost',
#  'wider',
#  'pull',
#  'mean',
#  'expensive',
#  'between',
#  'flat',
#  'our',
#  'heavier',
#  'seller',
#  'exchange',
#  'past',
#  'washing',
#  'torso',
#  'sweater',
#  'least',
#  'due',
#  'cool',
#  'difficult',
#  'instead',
#  'worked',
#  'tell',
#  'company',
#  'although',
#  'couldn',
#  'hole',
#  'tie',
#  'wait',
#  'giving',
#  'owned',
#  'online',
#  'opinion',
#  'thicker',
#  'worry',
#  'must',
#  'thigh',
#  'adorable',
#  'travel',
#  'collection',
#  'ago',
#  'mine',
#  'expecting',
#  'trying',
#  'pink',
#  'im',
#  'such',
#  'sol',
#  'night',
#  'aren',
#  'wrist',
#  'clothes',
#  'pay',
#  'guy',
#  'face',
#  'finally',
#  'away',
#  'classy',
#  'fitting',
#  'clothing',
#  'send',
#  'free',
#  'worried',
#  'man',
#  'gorgeous',
#  'weigh',
#  'soon',
#  'negative',
#  'mind',
#  'kid',
#  'green',
#  'hate',
#  'pack',
#  'comfortably',
#  'unless',
#  'discount',
#  'waistband',
#  'legging',
#  'sport',
#  'each',
#  'hot',
#  'cannot',
#  'compartment',
#  'stitching',
#  'making',
#  'hip',
#  'neck',
#  'completely',
#  'decided',
#  'flip',
#  'seemed',
#  'flop',
#  'point',
#  'darker',
#  'phone',
#  'saw',
#  'scarf',
#  'rain',
#  'image',
#  'amount',
#  'add',
#  'scrub',
#  'wasn',
#  'until',
#  'washed',
#  'forward',
#  'opening',
#  'height',
#  'else',
#  'simple',
#  'somewhat',
#  'sized',
#  'let',
#  'lost',
#  'fast',
#  'underneath',
#  'future',
#  'pain',
#  'based',
#  'hiking',
#  'skinny',
#  'elegant',
#  'beach',
#  'period',
#  'smooth',
#  'holding',
#  'impressed',
#  'liking',
#  'cold',
#  'start',
#  'across',
#  'party',
#  'snow',
#  'waterproof',
#  'wonderful',
#  'hit',
#  'metal',
#  'sometimes',
#  'broke',
#  'keeping',
#  'rather',
#  'left',
#  'during',
#  'twice',
#  'slide',
#  'breathable',
#  'class',
#  'original',
#  'eye',
#  'outfit',
#  'everyone',
#  'clasp',
#  'shorter',
#  'mom',
#  'started',
#  'backpack',
#  'yes',
#  'believe',
#  'sent',
#  'held',
#  'finger',
#  'skin',
#  'hurt',
#  'working',
#  'feature',
#  'unfortunately',
#  'please',
#  'home',
#  'choice',
#  'idea',
#  'fun',
#  'slim',
#  'mesh',
#  'higher',
#  'dressy',
#  'easier',
#  'addition',
#  'usual',
#  'attractive',
#  'decent',
#  'tiny',
#  'live',
#  'space',
#  'child',
#  'pearl',
#  'plenty',
#  'hang',
#  'etc',
#  'smell',
#  'ended',
#  'match',
#  'hook',
#  'coming',
#  'paid',
#  'care',
#  'stick',
#  'move',
#  'trail',
#  'cushioning',
#  'rubber',
#  'layer',
#  'chart',
#  'barely',
#  'lower',
#  'tad',
#  'stuff',
#  'accurate',
#  'tag',
#  'wouldn',
#  'plan',
#  'shown',
#  'purpose',
#  'touch',
#  'shrink',
#  'gym',
#  'average',
#  'petite',
#  'mid',
#  'reading',
#  'excited',
#  'velcro',
#  'lining',
#  'sexy',
#  'rest',
#  'family',
#  'roomy',
#  'xxl',
#  'rose',
#  'course',
#  'doing',
#  'appears',
#  'glass',
#  'coat',
#  'adjust',
#  'car',
#  'despite',
#  'robe',
#  'weekend',
#  'anyway',
#  'stand',
#  'exact',
#  'secure',
#  'immediately',
#  'close',
#  'model',
#  'wet',
#  'unbiased',
#  'fleece',
#  'thank',
#  'name',
#  'navy',
#  'detail',
#  'correct',
#  'fell',
#  'particular',
#  'trouble',
#  'video',
#  'done',
#  'together',
#  'sweat',
#  'handle',
#  'supportive',
#  'stone',
#  'mother',
#  'prefer',
#  'cross',
#  'above',
#  'hopefully',
#  'four',
#  'minute',
#  'near',
#  'suede',
#  'comment',
#  'collar',
#  'similar',
#  'fantastic',
#  'slight',
#  'totally',
#  'purple',
#  'professional',
#  'broken',
#  'below',
#  'described',
#  'lighter',
#  'ride',
#  'school',
#  'luggage',
#  'suggest',
#  'customer',
#  'sun',
#  'breast',
#  'levi',
#  'offer',
#  'halloween',
#  'insole',
#  'form',
#  'boyfriend',
#  'bonus',
#  'granddaughter',
#  'helpful',
#  'chose',
#  'tan',
#  'matter',
#  'provide',
#  'pattern',
#  'afraid',
#  'main',
#  'reviewer',
#  'pajama',
#  'five',
#  'insert',
#  'pro',
#  'office',
#  'turned',
#  'fitted',
#  'given',
#  'question',
#  'fairly',
#  'china',
#  'boy',
#  'brief',
#  'garment',
#  'cause',
#  'difference',
#  'ran',
#  'snap',
#  'third',
#  'thinner',
#  'sewn',
#  'priced',
#  'grandson',
#  'dryer',
#  'age',
#  'available',
#  'quick',
#  'except',
#  'print',
#  'spring',
#  'chuck',
#  'occasion',
#  'compared',
#  'baggy',
#  'link',
#  'discounted',
#  'straight',
#  'heat',
#  'incredibly',
#  'con',
#  'shade',
#  'zip',
#  'padding',
#  'whole',
#  'check',
#  'rub',
#  'everywhere',
#  'lady',
#  'seen',
#  'flexible',
#  'provided',
#  'date',
#  'chance',
#  'tend',
#  'turn',
#  'weird',
#  'package',
#  'setting',
#  'service',
#  'cushion',
#  'sale',
#  'allow',
#  'brim',
#  'luck',
#  'option',
#  'feeling',
#  'including',
#  'ton',
#  'colored',
#  'along',
#  'taking',
#  'pictured',
#  'description',
#  'com',
#  'play',
#  'sunglass',
#  'instruction',
#  'honestly',
#  'id',
#  'hair',
#  'roll',
#  'nursing',
#  'multiple',
#  'tummy',
#  'receive',
#  'leave',
#  'credit',
#  'typically',
#  'poor',
#  'today',
#  'expectation',
#  'later',
#  'feminine',
#  'satisfied',
#  'against',
#  'apart',
#  'experience',
#  'thinking',
#  'wow',
#  'construction',
#  'grip',
#  'edge',
#  'built',
#  'clark',
#  'underwear',
#  'test',
#  'standard',
#  'actual',
#  'figure',
#  'figured',
#  'nd',
#  'loop',
#  'versatile',
#  'taste',
#  'standing',
#  'yellow',
#  'noticed',
#  'stretched',
#  'bend',
#  'post',
#  'adult',
#  'middle',
#  'athletic',
#  'thanks',
#  'classic',
#  'knew',
#  'word',
#  'wheel',
#  'bother',
#  'literally',
#  'functional',
#  'delivered',
#  'within',
#  'considering',
#  'tom',
#  'non',
#  'sleep',
#  'condition',
#  'closure',
#  'cozy',
#  'local',
#  'breaking',
#  'looser',
#  'ear',
#  'umbrella',
#  'rough',
#  'number',
#  'mentioned',
#  'shock',
#  'section',
#  'drawstring',
#  'obviously',
#  'clog',
#  'sort',
#  'stated',
#  'replacement',
#  'rise',
#  'function',
#  'terrible',
#  'spot',
#  'perhaps',
#  'blister',
#  'clear',
#  'label',
#  'certainly',
#  'sit',
#  'timberland',
#  'simply',
#  'lock',
#  'version',
#  'covered',
#  'typical',
#  'tear',
#  ...]

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('nice', 0.9505600333213806),
#  ('quality', 0.9313877820968628),
#  ('pretty', 0.9219816327095032),
#  ('wallet', 0.9066296815872192),
#  ('really', 0.9058883190155029),
#  ('light', 0.8968765735626221),
#  ('beautiful', 0.8788192272186279),
#  ('very', 0.8767921924591064),
#  ('vibrant', 0.8756933808326721),
#  ('made', 0.8719553351402283)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# Out:
# ['granddaughter',
#  'love',
#  'it',
#  'bought',
#  'boxer',
#  'brief',
#  'for',
#  'my',
#  'daughter',
#  'and',
#  'she',
#  'loved',
#  'them']

# %%
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)

    return n.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)

# %%
from tqdm import tqdm

# %%
x = []
for i in tqdm(range(len(words))):
  x.append(avg_word2vec(words[i]))
# Out:
#  16%|█▌        | 604/3847 [00:00<00:00, 6034.74it/s]/usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 3847/3847 [00:02<00:00, 1773.62it/s]

# %%
len(x)
# Out:
# 3847

# %%
x[1]
# Out:
# array([-0.05089099,  0.21343303, -0.14411077,  0.18222211, -0.27025607,
#        -0.49580714, -0.24368605,  0.6520043 , -0.21187423, -0.35475972,
#         0.04108125, -0.3816574 , -0.10368793,  0.33787963,  0.5284195 ,
#         0.09367485,  0.2959649 , -0.33440578,  0.03172103, -0.44137523,
#         0.33555987,  0.36233217,  0.19545594,  0.20837119, -0.35364372,
#         0.22031225, -0.3588107 , -0.04234188, -0.13023683,  0.14750032,
#         0.42102656,  0.47390312,  0.14442995, -0.50252926,  0.20503782,
#         0.4995938 ,  0.03664722, -0.21587928, -0.32735655, -0.19807695,
#         0.04559149, -0.19874237,  0.0258769 ,  0.38516074,  0.23764339,
#         0.245318  , -0.30904722,  0.262983  ,  0.00721111,  0.19606447,
#         0.5580656 ,  0.01162248, -0.29312542,  0.06800094,  0.5110933 ,
#         0.44383276,  0.67178905, -0.1170842 , -0.24401554,  0.31412166,
#         0.11195518,  0.15538153, -0.211454  ,  0.12107687, -0.43405014,
#         0.42384937, -0.21512696,  0.5967044 , -0.3183638 ,  0.25091746,
#         0.17908771, -0.2841533 ,  0.6141063 , -0.05378321,  0.8171472 ,
#         0.29561967,  0.14251117,  0.32275027, -0.2727953 , -0.21294911,
#        -0.38723177,  0.3093167 , -0.31173277,  0.33414343, -0.07499666,
#         0.14941306,  0.51588565,  0.3401739 ,  0.53697115,  0.12062614,
#         1.0435214 ,  0.23839481, -0.06091153,  0.13268416,  0.49702936,
#         0.45690167, -0.35422564, -0.00488517, -0.1689051 , -0.1526756 ],
#       dtype=float32)

# %%
y = review[list(map(lambda x: len(x)>0 ,corpus))]
y=p.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (3847,)

# %%
x[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
import pandas as p # Assuming 'p' is an alias for 'pandas'

## this is the final independent features
df=[]
for i in range(0,len(x)):
    # Access the NumPy array directly using indexing
    reshaped_data = x[i].reshape(1,-1)
    df.append(p.DataFrame(reshaped_data))

df=p.concat(df,ignore_index=True)

# Check the shapes of df and y before assignment
print(f"Shape of df: {df.shape}")
print(f"Shape of y: {y.shape}")

# If the shapes are mismatched, investigate the data
# to identify and correct the inconsistencies
# For example, you might need to filter or adjust
# either df or y to ensure they have the same number of rows.

# Here is a potential solution to handle the length mismatch, depending on the desired outcome
# Option 1: Truncate the longer array to match the shorter one (df)
y = y[:df.shape[0]]

# Option 2: Select only matching indices from both arrays
# common_indices = df.index.intersection(y.index)
# df = df.loc[common_indices]
# y = y.loc[common_indices]


df['Output']=y
# Out:
# Shape of df: (3847, 100)
# Shape of y: (3847,)
# <ipython-input-232-6d41e8e2af35>:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df=p.concat(df,ignore_index=True)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.283759 -0.395213 -0.169650 -0.048479 -0.493746 -0.594753 -0.348950
# 1 -0.050891  0.213433 -0.144111  0.182222 -0.270256 -0.495807 -0.243686
# 2  0.066321  0.221437 -0.133869  0.142569 -0.366410 -0.414173 -0.191484
# 3  0.105362 -0.155288 -0.004202  0.237091 -0.216150 -0.670998 -0.285576
# 4 -0.040296 -0.204967 -0.206542  0.088058 -0.453014 -0.689041 -0.554691
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.490551 -0.298541 -0.304496  ...  0.517277 -0.204488  0.123328  0.321654
# 1  0.652004 -0.211874 -0.354760  ...  0.238395 -0.060912  0.132684  0.497029
# 2  0.703061 -0.219655 -0.436895  ...  0.369289  0.275349  0.184548  0.618524
# 3  0.615974 -0.267190 -0.274462  ...  0.135049 -0.455238  0.070770  0.117997
# 4  0.597907 -0.485562 -0.351921  ...  0.335482 -0.240151 -0.006789  0.091558
#
#          95        96        97        98        99  Output
# 0 -0.050464  0.087234  0.051945 -0.279426 -0.228979    True
# 1  0.456902 -0.354226 -0.004885 -0.168905 -0.152676    True
# 2  0.175184 -0.351420 -0.164903  0.122389 -0.089680    True
# 3  0.225661 -0.206557 -0.066734 -0.053317 -0.030900    True
# 4 -0.027037 -0.048418 -0.076116 -0.138530 -0.122964    True
#
# [5 rows x 101 columns]

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.283759 -0.395213 -0.169650 -0.048479 -0.493746 -0.594753 -0.348950
# 1 -0.050891  0.213433 -0.144111  0.182222 -0.270256 -0.495807 -0.243686
# 2  0.066321  0.221437 -0.133869  0.142569 -0.366410 -0.414173 -0.191484
# 3  0.105362 -0.155288 -0.004202  0.237091 -0.216150 -0.670998 -0.285576
# 4 -0.040296 -0.204967 -0.206542  0.088058 -0.453014 -0.689041 -0.554691
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.490551 -0.298541 -0.304496  ...  0.517277 -0.204488  0.123328  0.321654
# 1  0.652004 -0.211874 -0.354760  ...  0.238395 -0.060912  0.132684  0.497029
# 2  0.703061 -0.219655 -0.436895  ...  0.369289  0.275349  0.184548  0.618524
# 3  0.615974 -0.267190 -0.274462  ...  0.135049 -0.455238  0.070770  0.117997
# 4  0.597907 -0.485562 -0.351921  ...  0.335482 -0.240151 -0.006789  0.091558
#
#          95        96        97        98        99  Output
# 0 -0.050464  0.087234  0.051945 -0.279426 -0.228979    True
# 1  0.456902 -0.354226 -0.004885 -0.168905 -0.152676    True
# 2  0.175184 -0.351420 -0.164903  0.122389 -0.089680    True
# 3  0.225661 -0.206557 -0.066734 -0.053317 -0.030900    True
# 4 -0.027037 -0.048418 -0.076116 -0.138530 -0.122964    True
#
# [5 rows x 101 columns]

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.283759 -0.395213 -0.169650 -0.048479 -0.493746 -0.594753 -0.348950
# 1 -0.050891  0.213433 -0.144111  0.182222 -0.270256 -0.495807 -0.243686
# 2  0.066321  0.221437 -0.133869  0.142569 -0.366410 -0.414173 -0.191484
# 3  0.105362 -0.155288 -0.004202  0.237091 -0.216150 -0.670998 -0.285576
# 4 -0.040296 -0.204967 -0.206542  0.088058 -0.453014 -0.689041 -0.554691
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.490551 -0.298541 -0.304496  ...  0.517277 -0.204488  0.123328  0.321654
# 1  0.652004 -0.211874 -0.354760  ...  0.238395 -0.060912  0.132684  0.497029
# 2  0.703061 -0.219655 -0.436895  ...  0.369289  0.275349  0.184548  0.618524
# 3  0.615974 -0.267190 -0.274462  ...  0.135049 -0.455238  0.070770  0.117997
# 4  0.597907 -0.485562 -0.351921  ...  0.335482 -0.240151 -0.006789  0.091558
#
#          95        96        97        98        99  Output
# 0 -0.050464  0.087234  0.051945 -0.279426 -0.228979    True
# 1  0.456902 -0.354226 -0.004885 -0.168905 -0.152676    True
# 2  0.175184 -0.351420 -0.164903  0.122389 -0.089680    True
# 3  0.225661 -0.206557 -0.066734 -0.053317 -0.030900    True
# 4 -0.027037 -0.048418 -0.076116 -0.138530 -0.122964    True
#
# [5 rows x 101 columns]

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
x=df
x.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
y=df['Output']

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
print(X_test)
# Out:
#              0         1         2         3         4         5         6  \
# 1434 -0.011009  0.005248 -0.199170 -0.027413 -0.158278 -0.331702  0.135615
# 3664  0.015200 -0.019282 -0.097632  0.036973 -0.103996 -0.416468  0.047263
# 1613 -0.045967 -0.036682 -0.211027  0.033765 -0.218023 -0.338176 -0.138113
# 2366  0.126949 -0.042023 -0.007565  0.218444 -0.152613 -0.562669 -0.084699
# 2930  0.109755  0.096242 -0.090015  0.064032 -0.136145 -0.422857  0.115717
# ...        ...       ...       ...       ...       ...       ...       ...
# 1347  0.132235  0.047859 -0.015595  0.265196 -0.235830 -0.595064 -0.151324
# 1023  0.115110 -0.036760  0.045713  0.277693 -0.308014 -0.797153 -0.293033
# 449  -0.131793 -0.172057 -0.166702  0.148409 -0.603665 -0.781888 -0.576905
# 2713 -0.016721 -0.078086 -0.112351  0.119424 -0.271543 -0.586033 -0.199066
# 376   0.008736  0.155520 -0.143704  0.329351 -0.310802 -0.544345 -0.486643
#
#              7         8         9  ...        91        92        93  \
# 1434  0.507639 -0.136492 -0.268329  ...  0.259030  0.061899  0.206002
# 3664  0.525937 -0.184276 -0.289334  ...  0.194942 -0.015324  0.144116
# 1613  0.587014 -0.202809 -0.506968  ...  0.291431  0.257801  0.274508
# 2366  0.624087 -0.226304 -0.325236  ...  0.084228 -0.220473  0.142806
# 2930  0.596847 -0.147343 -0.278642  ...  0.201148  0.102221  0.170603
# ...        ...       ...       ...  ...       ...       ...       ...
# 1347  0.542954 -0.266115 -0.265874  ...  0.118007 -0.279593  0.021551
# 1023  0.596106 -0.369177 -0.225125  ...  0.089883 -0.514686 -0.082836
# 449   0.667485 -0.411044 -0.257939  ...  0.500215 -0.178653  0.059141
# 2713  0.596794 -0.315379 -0.401799  ...  0.266357 -0.151355  0.152930
# 376   0.679398 -0.380860 -0.604803  ...  0.095383 -0.113111  0.114704
#
#             94        95        96        97        98        99  Output
# 1434  0.396569  0.103581 -0.006143 -0.188708  0.123949 -0.100428   False
# 3664  0.326440  0.173541 -0.019241 -0.150031  0.078910 -0.082450   False
# 1613  0.490403  0.187794 -0.094910 -0.170066 -0.133585 -0.216281   False
# 2366  0.201314  0.243513 -0.236401 -0.153694  0.014934 -0.061578   False
# 2930  0.390406  0.195601 -0.154955 -0.192988  0.150019 -0.041772   False
# ...        ...       ...       ...       ...       ...       ...     ...
# 1347  0.103322  0.120971 -0.266834 -0.127120  0.058200  0.028799   False
# 1023 -0.032922  0.125891 -0.219463 -0.078725  0.044289  0.037313   False
# 449   0.268502 -0.009385 -0.186131  0.012067 -0.180313 -0.054005    True
# 2713  0.246018  0.133590 -0.099969 -0.121977 -0.037112 -0.149695    True
# 376   0.293097  0.426329 -0.424939 -0.114135 -0.272960 -0.205853    True
#
# [769 rows x 101 columns]

# %%
y_train
# Out:
# 1974     True
# 3178     True
# 2426    False
# 433     False
# 817      True
#         ...
# 1131     True
# 1295    False
# 861      True
# 3509     True
# 3176     True
# Name: Output, Length: 3076, dtype: bool

# %%
X_train.columns = X_train.columns.astype(str)
X_test.columns = X_test.columns.astype(str) # Apply the same change to X_test for consistency

from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       383
#         True       1.00      1.00      1.00       386
#
#     accuracy                           1.00       769
#    macro avg       1.00      1.00      1.00       769
# weighted avg       1.00      1.00      1.00       769

# %%
x_new='Love this!  Well made, sturdy, and very comfortable.  I love it!Very pretty'

# %%
corpus1 =[]

f_review1 = re.sub('[^a-zA-Z]',' ',x_new)
f_review1 = f_review1.lower()
f_review1 = f_review1.split()

f_review1 = [Le.lemmatize(word) for word in f_review1]
f_review1 = ' '.join(f_review1)
corpus1.append(f_review1)

# %%
[[i,j,k] for i,j,k in zip(list(map(len,corpus1)),corpus1, x) if i<1]
# Out:
# []

# %%
print(corpus1)
# Out:
# ['love this well made sturdy and very comfortable i love it very pretty']

# %%
words1 = []
for sent in corpus1:
  sent_token = sent_tokenize(sent)
  #print(sent_token)
  for sent in sent_token:
    #print(sent)
    words1.append(simple_preprocess(sent))
    #print(words1)

# %%
words1
# Out:
# [['love',
#   'this',
#   'well',
#   'made',
#   'sturdy',
#   'and',
#   'very',
#   'comfortable',
#   'love',
#   'it',
#   'very',
#   'pretty']]

# %%
x1 = []
for i in tqdm(range(len(words1))):
  x1.append(avg_word2vec(words1[i]))
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1572.08it/s]

# %%
len(x1)
# Out:
# 1

# %%
x1[0]
# Out:
# array([-0.01207681, -0.22168219, -0.24514498, -0.00153283, -0.60892534,
#        -0.7245135 , -0.6266366 ,  0.6918266 , -0.4928408 , -0.18318413,
#         0.16814531,  0.245384  , -0.14555453,  0.37485752,  0.38471687,
#         0.5219118 ,  0.86415416, -0.7105543 , -0.2823414 , -0.4653038 ,
#         0.3809156 ,  0.1698814 ,  0.17864496, -0.41971922,  0.339722  ,
#         0.07128174, -0.18635823,  0.72791773,  0.33703133,  0.6543918 ,
#         1.1335384 ,  0.7520183 ,  0.22861458, -0.8662427 ,  0.03275577,
#         0.21481198,  0.03060497, -0.23452699, -0.19819504, -0.22625019,
#         0.16924547, -0.12630671,  0.02887866,  0.28527734, -0.00874123,
#         0.05667439, -0.44991434,  0.5588663 ,  0.0682319 ,  0.4752538 ,
#         0.31717804,  0.10076816, -0.4158132 ,  0.5669542 ,  0.58202285,
#         0.7269571 ,  0.57235307,  0.376251  ,  0.13330673, -0.10795161,
#        -0.03670399, -0.10285497,  0.38973868,  0.10016885, -0.39869252,
#         0.88863593, -0.3218439 ,  0.20503306, -0.19979544,  0.49747014,
#         0.45517102,  0.1270831 ,  0.5245796 ,  0.43323097,  0.5358896 ,
#        -0.19394572,  0.51761836, -0.17575152, -0.30802423,  0.18060686,
#        -0.24959181,  0.7614916 , -0.52975196,  0.29857644, -0.50385255,
#        -0.51154333,  0.42077395,  0.07981147,  0.33216617,  0.6433702 ,
#         0.46330664,  0.56634885, -0.00907395,  0.03582278,  0.19689439,
#        -0.24124227, -0.12966998, -0.0231389 ,  0.03882587, -0.06575125],
#       dtype=float32)

# %%
import pandas as pd
import numpy as np

# Assuming your original dataset has a column named 'target' containing the labels
# Replace 'target' with the actual column name if different
target_variable = [text['target'] for text in corpus1 if isinstance(text, dict) and 'target' in text]  # extract target variable from your original data

# Apply the same filtering used for x_new to the target variable
y_new = [target_variable[i] for i in range(len(target_variable)) if len(corpus1[i]) > 0]
# Convert y_new to a numpy array for further processing if necessary
y_new = np.array(y_new)

# %%
print(y_new)
# Out:
# []

# %%
import pandas as p # Assuming 'p' is an alias for 'pandas'

## this is the final independent features
df1=[]

    # Convert the Series to a NumPy array and then reshape
reshaped_data1 = x1.iloc.values.reshape(1,-1)
df1.append(p.DataFrame(reshaped_data1))

df1=p.concat(df1,ignore_index=True)

# Check the shapes of df and y before assignment
print(f"Shape of df: {df1.shape}")
print(f"Shape of y: {y.shape}")

# If the shapes are mismatched, investigate the data
# to identify and correct the inconsistencies
# For example, you might need to filter or adjust
# either df or y to ensure they have the same number of rows.

# Here is a potential solution to handle the length mismatch, depending on the desired outcome
# Option 1: Truncate the longer array to match the shorter one (df)
y = y[:df.shape[0]]

# Option 2: Select only matching indices from both arrays
# common_indices = df.index.intersection(y.index)
# df = df.loc[common_indices]
# y = y.loc[common_indices]


df1['Output']=y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-262-a4b842e874f8> in <cell line: 7>()
#       5
#       6     # Convert the Series to a NumPy array and then reshape
# ----> 7 reshaped_data1 = x1.iloc.values.reshape(1,-1)
#       8 df1.append(p.DataFrame(reshaped_data1))
#       9
#
# AttributeError: 'list' object has no attribute 'iloc'

# %%
import pandas as p # Assuming 'p' is an alias for 'pandas'

## this is the final independent features
df1=[]

# Access the numpy array directly using indexing
reshaped_data1 = x1[0].reshape(1,-1) # x1[0] accesses the NumPy array within the list
df1.append(p.DataFrame(reshaped_data1))

df1=p.concat(df1,ignore_index=True)

# Check the shapes of df and y before assignment
print(f"Shape of df: {df1.shape}")
print(f"Shape of y: {y.shape}")

# ... (rest of the code remains the same)

df1['Output']=y
# Out:
# Shape of df: (1, 100)
# Shape of y: (3845,)

# %%
df1.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.012077 -0.221682 -0.245145 -0.001533 -0.608925 -0.724513 -0.626637
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.691827 -0.492841 -0.183184  ...  0.566349 -0.009074  0.035823  0.196894
#
#          95       96        97        98        99  Output
# 0 -0.241242 -0.12967 -0.023139  0.038826 -0.065751    True
#
# [1 rows x 101 columns]

# %%
df1.dropna(inplace=True)

# %%
df1.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.012077 -0.221682 -0.245145 -0.001533 -0.608925 -0.724513 -0.626637
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.691827 -0.492841 -0.183184  ...  0.566349 -0.009074  0.035823  0.196894
#
#          95       96        97        98        99  Output
# 0 -0.241242 -0.12967 -0.023139  0.038826 -0.065751    True
#
# [1 rows x 101 columns]

# %%
df1.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
x=df1
x.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
x.columns = x.columns.astype(str)
y_pred1 = classifier.predict(x)

# %%
# Store the index of df1 before dropping rows
original_index = df1.index

# ... your existing code for dropping rows and prediction ...

# Create a new DataFrame with the original index
y_pred_df = pd.DataFrame(y_pred1, index=original_index, columns=['Prediction'])

# Reindex to include all original rows (fill missing with NaN)
y_pred_df = y_pred_df.reindex(df1.index)

# Convert predictions to True/False
y_pred_df['Prediction'] = y_pred_df['Prediction'].astype(bool)

# Now y_pred_df will have the same size as df1
print(y_pred_df)
# Out:
#    Prediction
# 0        True

# %%
x.size
# Out:
# 101
